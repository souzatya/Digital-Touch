# %% [markdown]
# ### 4 Objects Classification

# %%
# importing libraries
import math
import tensorflow as tf
import keras
from keras.layers import *
import numpy as np
import random
import io
import os
from sklearn.model_selection import train_test_split
from keras.activations import tanh, softmax, sigmoid
from keras.applications.inception_resnet_v2 import InceptionResNetV2
import tensorflow as tf
import random
import os
import keras
import matplotlib.pyplot as plt
import pandas as pd
from keras.layers import (
    LSTM,
    LSTMCell,
    Input,
    Dense,
    concatenate,
    TimeDistributed,
    Flatten,
    Dropout,
    Masking,
    RepeatVector,
    GlobalAveragePooling2D,
    GlobalMaxPooling2D,
    Reshape,
    multiply,
    Permute,
    Concatenate,
    Conv2D,
    Add,
    Activation,
    Lambda,
    BatchNormalization
)
from keras import backend as K, Model
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import precision_score, recall_score, f1_score
# Out:
# 2024-10-25 12:38:25.868805: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-25 12:38:25.947788: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-25 12:38:26.028426: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-25 12:38:26.053173: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-25 12:38:26.107835: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-25 12:38:28.944521: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# List all physical GPUs
gpus = tf.config.list_physical_devices('GPU')
print("Available GPUs:", gpus)

if gpus:
    try:
        # Select the first GPU (index 0)
        tf.config.set_visible_devices(gpus[5], 'GPU')

        # Optionally, limit GPU memory growth (prevents TensorFlow from consuming all GPU memory)
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        
        print("Using GPU:", gpus[5])
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:4', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:5', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:6', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:7', device_type='GPU')]
# Using GPU: PhysicalDevice(name='/physical_device:GPU:5', device_type='GPU')

# %%
# hard objects
plate = np.asarray([1, 0, 0, 0])
# soft objects
phone_cover = np.asarray([0, 1, 0, 0])
bottle = np.asarray([0, 0, 1, 0])
soft_rubber = np.asarray([0, 0, 0, 1])

# %%
encoded_objects = [plate, phone_cover, bottle, soft_rubber]

# %%
encoded_objects
# Out:
# [array([1, 0, 0, 0]),
#  array([0, 1, 0, 0]),
#  array([0, 0, 1, 0]),
#  array([0, 0, 0, 1])]

# %%
# reading a numpy file
data_dir = './train_val_data'
samples_per_window = 30

def read_npy_files(directory):
  data = []
  labels = []
  i = 0
  for filename in os.listdir(directory):
    if filename.endswith(".npy"):
      base_name = os.path.splitext(filename)[0]
      data.append(np.load(os.path.join(directory, filename), allow_pickle = True))
      # for labelling objects = ['plate', 'ball', 'cover', 'bottle', 'soft_rubber']
      if 'plate' in filename :
          labels.append(np.tile(encoded_objects[0], (samples_per_window, 1)))
      elif 'phone' in filename and 'cover' in filename :
          labels.append(np.tile(encoded_objects[1], (samples_per_window, 1)))
      elif 'bottle' in filename :
          labels.append(np.tile(encoded_objects[2], (samples_per_window, 1)))
      elif 'rubber' in filename :
          labels.append(np.tile(encoded_objects[3], (samples_per_window, 1)))
  return data, labels

all_data, labels = read_npy_files(data_dir)

# converting to numpy array
all_data = np.asarray(all_data)[:, :, :, 1:].astype(np.float32)
labels = np.asarray(labels).astype(np.float32)

# %%
all_data.shape
# Out:
# (12, 8, 30, 3)

# %%
labels.shape
# Out:
# (12, 30, 4)

# %% [markdown]
# Spitting of the train and val dataset

# %%
train_all_data = []
val_all_data = []
test_all_data =[]
train_labels = []
val_labels = []
test_labels = []
total_samples = 8
val_samples = 1
test_samples = 1
train_samples = total_samples - val_samples - test_samples


for data in all_data:
  for i in range(train_samples):
    train_all_data.append(data[i])
  for i in range(val_samples):
    val_all_data.append(data[train_samples + i])
  for i in range(test_samples):
    test_all_data.append(data[train_samples + val_samples + i])

for label in labels:
  # label = np.expand_dims(label[1, :], axis = 0)
  # print(np.asarray(label).shape)
  for i in range(train_samples):
    train_labels.append(label[1, :])
  for i in range(val_samples):
    val_labels.append(label[1, :])
  for i in range(test_samples):
    test_labels.append(label[1, :])

# %%
# hyperpaprametres
TIME_STEPS = 30
input_dim  = 3
output_dim = 4

# %%
class CNN_GRU_Model(tf.keras.Model):
    def __init__(self):
        super(CNN_GRU_Model, self).__init__()

        # # 1D Convolutional layers (CNN part)
        # self.conv1 = Conv1D(32, kernel_size=3, strides=1, activation='relu')
        # self.conv2 = Conv1D(64, kernel_size=3, strides=2, activation='relu')
        # self.conv3 = Conv1D(128, kernel_size=3, strides=5, activation='relu')

        # # Batch Normalization layers
        # self.bn1 = BatchNormalization()
        # self.bn2 = BatchNormalization()

        # # Max Pooling layer
        # self.max_pool = MaxPooling1D(pool_size=2, strides=2)

        # GRU layer
        self.gru = GRU(1024)

        # Fully connected layer
        self.fc = Dense(4, activation='softmax')  # Output layer for 4-class classification

    def call(self, inputs):
        # x_cnn, x_gru = inputs
        x_gru = inputs

        # # CNN forward pass on (30, 3) input
        # x_cnn = self.conv1(x_cnn)
        # x_cnn = self.conv2(x_cnn)
        # x_cnn = self.bn1(x_cnn)
        # x_cnn = self.max_pool(x_cnn)
        # x_cnn = self.conv3(x_cnn)
        # x_cnn = self.bn2(x_cnn)
        # x_cnn = Flatten()(x_cnn)

        # GRU forward pass on (30, 3) input
        x_gru = self.gru(x_gru)

        # Concatenate CNN and GRU outputs
        # x = Concatenate()([x_cnn, x_gru])

        # Fully connected layer
        x = self.fc(x_gru)

        return x
    
    def generate(self):
        # Input for CNN (time series data with shape (30, 3))
        # cnn_input = Input(shape=(30, 3), name='cnn_input')

        # Input for GRU (time series data with shape (30, 3))
        gru_input = Input(shape=(30, 3), name='gru_input')

        # Call the model's main forward pass (call method) with the inputs
        # output = self.call([cnn_input, gru_input])
        output = self.call(gru_input)

        # Create a Keras Model instance
        # model = Model(inputs=[cnn_input, gru_input], outputs=output)
        model = Model(inputs= gru_input, outputs=output)

        return model

# %%
cnn_gru = CNN_GRU_Model()
model = cnn_gru.generate()

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_input (InputLayer)          │ (None, 30, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 1024)           │     3,161,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         4,100 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,165,188 (12.07 MB)
#  Trainable params: 3,165,188 (12.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint_filepath = 'checkpoint_4obj_model_gru.keras'
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath = checkpoint_filepath,
    monitor = 'val_f1_score',
    mode = 'max',
    verbose = 1,
    save_best_only = True,
    save_weights_only = False)

precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()

def f1_score(y_true, y_pred):
    precision_value = precision(y_true, y_pred)
    recall_value = recall(y_true, y_pred)
    f1 = 2 * ((precision_value * recall_value) / (precision_value + recall_value + tf.keras.backend.epsilon()))
    return f1

# Early stopping criteria
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 3)

initial_lr = 1e-3
decay_rate = 0.5
# val_acc_list = np.asarray(history.history['val_accuracy'])
# max_val_acc = (val_acc_list).max()
# print(max_val_acc, np.where(val_acc_list == max_val_acc)[0] + 1)
optimizer = keras.optimizers.Adam(learning_rate = initial_lr)

model.compile( loss = 'categorical_crossentropy', metrics = ['accuracy', precision, recall, f1_score])

class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, validation_data):
        super(MetricsCallback, self).__init__()
        self.validation_data = validation_data
    def on_epoch_end(self, epoch, logs = None):
        lr = self.model.optimizer.learning_rate
        print(f"\nEpoch {epoch + 1}: Learning Rate = {lr.numpy()}")

class ReduceLROnPlateau(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs = None):
        # Decrease learning rate by 0.1 after each epoch
        lr = float(K.get_value(optimizer.learning_rate))
        if lr > 3.4e-44:
            lr = lr * 0.1
        K.set_value(optimizer.learning_rate, lr)
        print(f"\nEpoch {epoch + 1}: New Learning Rate = {lr}")

# converting the numpy arrays into tensor
train_data_tf = tf.convert_to_tensor(train_all_data)
train_labels_tf = tf.convert_to_tensor(train_labels)
val_data_tf = tf.convert_to_tensor(val_all_data)
val_labels_tf = tf.convert_to_tensor(val_labels)
validation_data = (val_data_tf, val_labels_tf)

# training and validating step
history = model.fit(train_data_tf, train_labels_tf, epochs = 2000, batch_size = 128,
          validation_data = validation_data, callbacks = [model_checkpoint_callback, MetricsCallback(validation_data)])

# for tracking the maximum validation accuracy ata particular epoch
# val_acc_list = np.asarray(history.history['val_accuracy'])
# max_val_acc = (val_acc_list).max()
# print(max_val_acc, np.where(val_acc_list == max_val_acc)[0] + 1)

# plotting the graph
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_accuracy'], label='validaton accuracy')
plt.plot(history.history['val_f1_score'], label='Validaton F-score')
plt.title('Training and Validation Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/2000
# 2024-10-25 12:39:43.067977: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2500 - f1_score: 0.0889 - loss: 1.5735 - precision: 0.2222 - recall: 0.0556
# Epoch 1: val_f1_score improved from -inf to 0.25000, saving model to checkpoint_4obj_model_cnn_gru.keras
#
# Epoch 1: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.2500 - f1_score: 0.0889 - loss: 1.5735 - precision: 0.2222 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.2500 - val_loss: 10.2259 - val_precision: 0.2500 - val_recall: 0.2500
# Epoch 2/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.2500 - f1_score: 0.2500 - loss: 10.2155 - precision: 0.2500 - recall: 0.2500
# Epoch 2: val_f1_score did not improve from 0.25000
#
# Epoch 2: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.2500 - f1_score: 0.2500 - loss: 10.2155 - precision: 0.2500 - recall: 0.2500 - val_accuracy: 0.2500 - val_f1_score: 0.2500 - val_loss: 10.1741 - val_precision: 0.2500 - val_recall: 0.2500
# Epoch 3/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.2500 - f1_score: 0.2500 - loss: 10.1103 - precision: 0.2500 - recall: 0.2500
# Epoch 3: val_f1_score did not improve from 0.25000
#
# Epoch 3: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.2500 - f1_score: 0.2500 - loss: 10.1103 - precision: 0.2500 - recall: 0.2500 - val_accuracy: 0.2500 - val_f1_score: 0.2500 - val_loss: 5.6566 - val_precision: 0.2500 - val_recall: 0.2500
# Epoch 4/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.2500 - f1_score: 0.2500 - loss: 5.6834 - precision: 0.2500 - recall: 0.2500
# Epoch 4: val_f1_score did not improve from 0.25000
#
# Epoch 4: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.2500 - f1_score: 0.2500 - loss: 5.6834 - precision: 0.2500 - recall: 0.2500 - val_accuracy: 0.1667 - val_f1_score: 0.2353 - val_loss: 2.4605 - val_precision: 0.4000 - val_recall: 0.1667
# Epoch 5/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.1528 - f1_score: 0.2020 - loss: 2.4403 - precision: 0.3704 - recall: 0.1389
# Epoch 5: val_f1_score did not improve from 0.25000
#
# Epoch 5: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.1528 - f1_score: 0.2020 - loss: 2.4403 - precision: 0.3704 - recall: 0.1389 - val_accuracy: 0.2500 - val_f1_score: 0.2500 - val_loss: 2.3597 - val_precision: 0.2500 - val_recall: 0.2500
# Epoch 6/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2500 - f1_score: 0.2500 - loss: 2.3774 - precision: 0.2500 - recall: 0.2500
# Epoch 6: val_f1_score improved from 0.25000 to 0.34783, saving model to checkpoint_4obj_model_cnn_gru.keras
#
# Epoch 6: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - accuracy: 0.2500 - f1_score: 0.2500 - loss: 2.3774 - precision: 0.2500 - recall: 0.2500 - val_accuracy: 0.3333 - val_f1_score: 0.3478 - val_loss: 2.2633 - val_precision: 0.3636 - val_recall: 0.3333
# Epoch 7/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.2917 - f1_score: 0.3066 - loss: 2.2363 - precision: 0.3231 - recall: 0.2917
# Epoch 7: val_f1_score improved from 0.34783 to 0.36364, saving model to checkpoint_4obj_model_cnn_gru.keras
#
# Epoch 7: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.2917 - f1_score: 0.3066 - loss: 2.2363 - precision: 0.3231 - recall: 0.2917 - val_accuracy: 0.4167 - val_f1_score: 0.3636 - val_loss: 1.8176 - val_precision: 0.4000 - val_recall: 0.3333
# Epoch 8/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.3750 - f1_score: 0.3529 - loss: 1.8200 - precision: 0.3750 - recall: 0.3333
# Epoch 8: val_f1_score did not improve from 0.36364
#
# Epoch 8: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.3750 - f1_score: 0.3529 - loss: 1.8200 - precision: 0.3750 - recall: 0.3333 - val_accuracy: 0.3333 - val_f1_score: 0.2353 - val_loss: 1.4442 - val_precision: 0.4000 - val_recall: 0.1667
# Epoch 9/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3611 - f1_score: 0.2222 - loss: 1.4606 - precision: 0.4074 - recall: 0.1528
# Epoch 9: val_f1_score did not improve from 0.36364
#
# Epoch 9: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.3611 - f1_score: 0.2222 - loss: 1.4606 - precision: 0.4074 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.2222 - val_loss: 1.5209 - val_precision: 0.3333 - val_recall: 0.1667
# Epoch 10/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.2500 - f1_score: 0.2000 - loss: 1.4971 - precision: 0.3571 - recall: 0.1389
# Epoch 10: val_f1_score did not improve from 0.36364
#
# Epoch 10: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.2500 - f1_score: 0.2000 - loss: 1.4971 - precision: 0.3571 - recall: 0.1389 - val_accuracy: 0.3333 - val_f1_score: 0.2353 - val_loss: 1.4253 - val_precision: 0.4000 - val_recall: 0.1667
# Epoch 11/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.3333 - f1_score: 0.0909 - loss: 1.4561 - precision: 0.2500 - recall: 0.0556
# Epoch 11: val_f1_score did not improve from 0.36364
#
# Epoch 11: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.3333 - f1_score: 0.0909 - loss: 1.4561 - precision: 0.2500 - recall: 0.0556 - val_accuracy: 0.3333 - val_f1_score: 0.2353 - val_loss: 1.4260 - val_precision: 0.4000 - val_recall: 0.1667
# Epoch 12/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.3194 - f1_score: 0.2083 - loss: 1.4048 - precision: 0.4167 - recall: 0.1389
# Epoch 12: val_f1_score did not improve from 0.36364
#
# Epoch 12: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.3194 - f1_score: 0.2083 - loss: 1.4048 - precision: 0.4167 - recall: 0.1389 - val_accuracy: 0.3333 - val_f1_score: 0.1333 - val_loss: 1.3648 - val_precision: 0.3333 - val_recall: 0.0833
# Epoch 13/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.2917 - f1_score: 0.0471 - loss: 1.3861 - precision: 0.1538 - recall: 0.0278
# Epoch 13: val_f1_score did not improve from 0.36364
#
# Epoch 13: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.2917 - f1_score: 0.0471 - loss: 1.3861 - precision: 0.1538 - recall: 0.0278 - val_accuracy: 0.4167 - val_f1_score: 0.2500 - val_loss: 1.3845 - val_precision: 0.5000 - val_recall: 0.1667
# Epoch 14/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.4028 - f1_score: 0.2222 - loss: 1.3620 - precision: 0.5556 - recall: 0.1389
# Epoch 14: val_f1_score did not improve from 0.36364
#
# Epoch 14: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.4028 - f1_score: 0.2222 - loss: 1.3620 - precision: 0.5556 - recall: 0.1389 - val_accuracy: 0.3333 - val_f1_score: 0.2353 - val_loss: 1.3427 - val_precision: 0.4000 - val_recall: 0.1667
# Epoch 15/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3750 - f1_score: 0.0476 - loss: 1.3563 - precision: 0.1667 - recall: 0.0278
# Epoch 15: val_f1_score did not improve from 0.36364
#
# Epoch 15: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.3750 - f1_score: 0.0476 - loss: 1.3563 - precision: 0.1667 - recall: 0.0278 - val_accuracy: 0.2500 - val_f1_score: 0.2500 - val_loss: 1.3907 - val_precision: 0.5000 - val_recall: 0.1667
# Epoch 16/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.3056 - f1_score: 0.2222 - loss: 1.3635 - precision: 0.5556 - recall: 0.1389
# Epoch 16: val_f1_score did not improve from 0.36364
#
# Epoch 16: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3056 - f1_score: 0.2222 - loss: 1.3635 - precision: 0.5556 - recall: 0.1389 - val_accuracy: 0.4167 - val_f1_score: 0.2353 - val_loss: 1.3472 - val_precision: 0.4000 - val_recall: 0.1667
# Epoch 17/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4444 - f1_score: 0.2062 - loss: 1.3537 - precision: 0.4000 - recall: 0.1389
# Epoch 17: val_f1_score did not improve from 0.36364
#
# Epoch 17: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.4444 - f1_score: 0.2062 - loss: 1.3537 - precision: 0.4000 - recall: 0.1389 - val_accuracy: 0.3333 - val_f1_score: 0.2500 - val_loss: 1.4148 - val_precision: 0.5000 - val_recall: 0.1667
# Epoch 18/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.3194 - f1_score: 0.2045 - loss: 1.3857 - precision: 0.5625 - recall: 0.1250
# Epoch 18: val_f1_score did not improve from 0.36364
#
# Epoch 18: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.3194 - f1_score: 0.2045 - loss: 1.3857 - precision: 0.5625 - recall: 0.1250 - val_accuracy: 0.3333 - val_f1_score: 0.2353 - val_loss: 1.3516 - val_precision: 0.4000 - val_recall: 0.1667
# Epoch 19/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.3611 - f1_score: 0.2400 - loss: 1.3492 - precision: 0.4286 - recall: 0.1667
# Epoch 19: val_f1_score did not improve from 0.36364
#
# Epoch 19: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.3611 - f1_score: 0.2400 - loss: 1.3492 - precision: 0.4286 - recall: 0.1667 - val_accuracy: 0.3333 - val_f1_score: 0.1333 - val_loss: 1.4362 - val_precision: 0.3333 - val_recall: 0.0833
# Epoch 20/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.3472 - f1_score: 0.2069 - loss: 1.4104 - precision: 0.6000 - recall: 0.1250
# Epoch 20: val_f1_score did not improve from 0.36364
#
# Epoch 20: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.3472 - f1_score: 0.2069 - loss: 1.4104 - precision: 0.6000 - recall: 0.1250 - val_accuracy: 0.4167 - val_f1_score: 0.2353 - val_loss: 1.3636 - val_precision: 0.4000 - val_recall: 0.1667
# Epoch 21/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4167 - f1_score: 0.2376 - loss: 1.3487 - precision: 0.4138 - recall: 0.1667
# Epoch 21: val_f1_score did not improve from 0.36364
#
# Epoch 21: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.4167 - f1_score: 0.2376 - loss: 1.3487 - precision: 0.4138 - recall: 0.1667 - val_accuracy: 0.4167 - val_f1_score: 0.1429 - val_loss: 1.4425 - val_precision: 0.5000 - val_recall: 0.0833
# Epoch 22/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.3750 - f1_score: 0.1951 - loss: 1.4279 - precision: 0.8000 - recall: 0.1111
# Epoch 22: val_f1_score did not improve from 0.36364
#
# Epoch 22: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.3750 - f1_score: 0.1951 - loss: 1.4279 - precision: 0.8000 - recall: 0.1111 - val_accuracy: 0.3333 - val_f1_score: 0.2500 - val_loss: 1.4320 - val_precision: 0.5000 - val_recall: 0.1667
# Epoch 23/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.3056 - f1_score: 0.2887 - loss: 1.3963 - precision: 0.5600 - recall: 0.1944
# Epoch 23: val_f1_score did not improve from 0.36364
#
# Epoch 23: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.3056 - f1_score: 0.2887 - loss: 1.3963 - precision: 0.5600 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.1538 - val_loss: 1.4346 - val_precision: 1.0000 - val_recall: 0.0833
# Epoch 24/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.3333 - f1_score: 0.1053 - loss: 1.4463 - precision: 1.0000 - recall: 0.0556
# Epoch 24: val_f1_score did not improve from 0.36364
#
# Epoch 24: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.3333 - f1_score: 0.1053 - loss: 1.4463 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.3333 - val_f1_score: 0.2353 - val_loss: 1.6424 - val_precision: 0.4000 - val_recall: 0.1667
# Epoch 25/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.3333 - f1_score: 0.2737 - loss: 1.5701 - precision: 0.5652 - recall: 0.1806
# Epoch 25: val_f1_score did not improve from 0.36364
#
# Epoch 25: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.3333 - f1_score: 0.2737 - loss: 1.5701 - precision: 0.5652 - recall: 0.1806 - val_accuracy: 0.3333 - val_f1_score: 0.0000e+00 - val_loss: 1.4898 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.3611 - f1_score: 0.0263 - loss: 1.5261 - precision: 0.2500 - recall: 0.0139
# Epoch 26: val_f1_score did not improve from 0.36364
#
# Epoch 26: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.3611 - f1_score: 0.0263 - loss: 1.5261 - precision: 0.2500 - recall: 0.0139 - val_accuracy: 0.4167 - val_f1_score: 0.1333 - val_loss: 1.5298 - val_precision: 0.3333 - val_recall: 0.0833
# Epoch 27/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4306 - f1_score: 0.2581 - loss: 1.4538 - precision: 0.5714 - recall: 0.1667
# Epoch 27: val_f1_score did not improve from 0.36364
#
# Epoch 27: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.4306 - f1_score: 0.2581 - loss: 1.4538 - precision: 0.5714 - recall: 0.1667 - val_accuracy: 0.5000 - val_f1_score: 0.0000e+00 - val_loss: 1.3153 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4167 - f1_score: 0.0541 - loss: 1.3266 - precision: 1.0000 - recall: 0.0278
# Epoch 28: val_f1_score did not improve from 0.36364
#
# Epoch 28: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.4167 - f1_score: 0.0541 - loss: 1.3266 - precision: 1.0000 - recall: 0.0278 - val_accuracy: 0.2500 - val_f1_score: 0.1333 - val_loss: 1.3670 - val_precision: 0.3333 - val_recall: 0.0833
# Epoch 29/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3194 - f1_score: 0.2198 - loss: 1.2986 - precision: 0.5263 - recall: 0.1389
# Epoch 29: val_f1_score did not improve from 0.36364
#
# Epoch 29: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.3194 - f1_score: 0.2198 - loss: 1.2986 - precision: 0.5263 - recall: 0.1389 - val_accuracy: 0.4167 - val_f1_score: 0.2500 - val_loss: 1.3341 - val_precision: 0.5000 - val_recall: 0.1667
# Epoch 30/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4583 - f1_score: 0.0723 - loss: 1.3345 - precision: 0.2727 - recall: 0.0417
# Epoch 30: val_f1_score did not improve from 0.36364
#
# Epoch 30: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.4583 - f1_score: 0.0723 - loss: 1.3345 - precision: 0.2727 - recall: 0.0417 - val_accuracy: 0.4167 - val_f1_score: 0.2222 - val_loss: 1.4540 - val_precision: 0.3333 - val_recall: 0.1667
# Epoch 31/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4306 - f1_score: 0.2400 - loss: 1.3751 - precision: 0.4286 - recall: 0.1667
# Epoch 31: val_f1_score did not improve from 0.36364
#
# Epoch 31: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.4306 - f1_score: 0.2400 - loss: 1.3751 - precision: 0.4286 - recall: 0.1667 - val_accuracy: 0.3333 - val_f1_score: 0.2222 - val_loss: 1.5286 - val_precision: 0.3333 - val_recall: 0.1667
# Epoch 32/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3472 - f1_score: 0.2453 - loss: 1.5135 - precision: 0.3824 - recall: 0.1806
# Epoch 32: val_f1_score did not improve from 0.36364
#
# Epoch 32: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.3472 - f1_score: 0.2453 - loss: 1.5135 - precision: 0.3824 - recall: 0.1806 - val_accuracy: 0.3333 - val_f1_score: 0.3000 - val_loss: 1.5845 - val_precision: 0.3750 - val_recall: 0.2500
# Epoch 33/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3333 - f1_score: 0.3590 - loss: 1.5300 - precision: 0.4667 - recall: 0.2917
# Epoch 33: val_f1_score did not improve from 0.36364
#
# Epoch 33: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.3333 - f1_score: 0.3590 - loss: 1.5300 - precision: 0.4667 - recall: 0.2917 - val_accuracy: 0.4167 - val_f1_score: 0.2222 - val_loss: 1.4429 - val_precision: 0.3333 - val_recall: 0.1667
# Epoch 34/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4306 - f1_score: 0.2364 - loss: 1.4145 - precision: 0.3421 - recall: 0.1806
# Epoch 34: val_f1_score did not improve from 0.36364
#
# Epoch 34: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.4306 - f1_score: 0.2364 - loss: 1.4145 - precision: 0.3421 - recall: 0.1806 - val_accuracy: 0.2500 - val_f1_score: 0.3000 - val_loss: 1.5177 - val_precision: 0.3750 - val_recall: 0.2500
# Epoch 35/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3333 - f1_score: 0.3158 - loss: 1.4619 - precision: 0.4286 - recall: 0.2500
# Epoch 35: val_f1_score did not improve from 0.36364
#
# Epoch 35: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.3333 - f1_score: 0.3158 - loss: 1.4619 - precision: 0.4286 - recall: 0.2500 - val_accuracy: 0.4167 - val_f1_score: 0.2105 - val_loss: 1.3950 - val_precision: 0.2857 - val_recall: 0.1667
# Epoch 36/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4444 - f1_score: 0.2545 - loss: 1.3555 - precision: 0.3684 - recall: 0.1944
# Epoch 36: val_f1_score did not improve from 0.36364
#
# Epoch 36: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4444 - f1_score: 0.2545 - loss: 1.3555 - precision: 0.3684 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.2857 - val_loss: 1.3941 - val_precision: 1.0000 - val_recall: 0.1667
# Epoch 37/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4306 - f1_score: 0.2989 - loss: 1.3406 - precision: 0.8667 - recall: 0.1806
# Epoch 37: val_f1_score did not improve from 0.36364
#
# Epoch 37: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.4306 - f1_score: 0.2989 - loss: 1.3406 - precision: 0.8667 - recall: 0.1806 - val_accuracy: 0.3333 - val_f1_score: 0.2500 - val_loss: 1.3503 - val_precision: 0.5000 - val_recall: 0.1667
# Epoch 38/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3889 - f1_score: 0.3636 - loss: 1.2976 - precision: 0.6667 - recall: 0.2500
# Epoch 38: val_f1_score did not improve from 0.36364
#
# Epoch 38: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.3889 - f1_score: 0.3636 - loss: 1.2976 - precision: 0.6667 - recall: 0.2500 - val_accuracy: 0.4167 - val_f1_score: 0.2353 - val_loss: 1.4277 - val_precision: 0.4000 - val_recall: 0.1667
# Epoch 39/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.4028 - f1_score: 0.2200 - loss: 1.3743 - precision: 0.3929 - recall: 0.1528
# Epoch 39: val_f1_score did not improve from 0.36364
#
# Epoch 39: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.4028 - f1_score: 0.2200 - loss: 1.3743 - precision: 0.3929 - recall: 0.1528 - val_accuracy: 0.3333 - val_f1_score: 0.3529 - val_loss: 1.4727 - val_precision: 0.6000 - val_recall: 0.2500
# Epoch 40/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.3333 - f1_score: 0.3636 - loss: 1.4015 - precision: 0.6667 - recall: 0.2500
# Epoch 40: val_f1_score did not improve from 0.36364
#
# Epoch 40: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.3333 - f1_score: 0.3636 - loss: 1.4015 - precision: 0.6667 - recall: 0.2500 - val_accuracy: 0.3333 - val_f1_score: 0.2353 - val_loss: 1.3860 - val_precision: 0.4000 - val_recall: 0.1667
# Epoch 41/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3472 - f1_score: 0.2376 - loss: 1.3391 - precision: 0.4138 - recall: 0.1667
# Epoch 41: val_f1_score did not improve from 0.36364
#
# Epoch 41: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.3472 - f1_score: 0.2376 - loss: 1.3391 - precision: 0.4138 - recall: 0.1667 - val_accuracy: 0.3333 - val_f1_score: 0.2500 - val_loss: 1.3979 - val_precision: 0.5000 - val_recall: 0.1667
# Epoch 42/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.3194 - f1_score: 0.3636 - loss: 1.3238 - precision: 0.6667 - recall: 0.2500
# Epoch 42: val_f1_score did not improve from 0.36364
#
# Epoch 42: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.3194 - f1_score: 0.3636 - loss: 1.3238 - precision: 0.6667 - recall: 0.2500 - val_accuracy: 0.4167 - val_f1_score: 0.2500 - val_loss: 1.3254 - val_precision: 0.5000 - val_recall: 0.1667
# Epoch 43/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4028 - f1_score: 0.2581 - loss: 1.2804 - precision: 0.5714 - recall: 0.1667
# Epoch 43: val_f1_score did not improve from 0.36364
#
# Epoch 43: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.4028 - f1_score: 0.2581 - loss: 1.2804 - precision: 0.5714 - recall: 0.1667 - val_accuracy: 0.3333 - val_f1_score: 0.2500 - val_loss: 1.3385 - val_precision: 0.5000 - val_recall: 0.1667
# Epoch 44/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3333 - f1_score: 0.3125 - loss: 1.2583 - precision: 0.6250 - recall: 0.2083
# Epoch 44: val_f1_score did not improve from 0.36364
#
# Epoch 44: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.3333 - f1_score: 0.3125 - loss: 1.2583 - precision: 0.6250 - recall: 0.2083 - val_accuracy: 0.5000 - val_f1_score: 0.1333 - val_loss: 1.3048 - val_precision: 0.3333 - val_recall: 0.0833
# Epoch 45/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5139 - f1_score: 0.1882 - loss: 1.2633 - precision: 0.6154 - recall: 0.1111
# Epoch 45: val_f1_score did not improve from 0.36364
#
# Epoch 45: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.5139 - f1_score: 0.1882 - loss: 1.2633 - precision: 0.6154 - recall: 0.1111 - val_accuracy: 0.3333 - val_f1_score: 0.2500 - val_loss: 1.3365 - val_precision: 0.5000 - val_recall: 0.1667
# Epoch 46/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3889 - f1_score: 0.2391 - loss: 1.2409 - precision: 0.5500 - recall: 0.1528
# Epoch 46: val_f1_score did not improve from 0.36364
#
# Epoch 46: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.3889 - f1_score: 0.2391 - loss: 1.2409 - precision: 0.5500 - recall: 0.1528 - val_accuracy: 0.5000 - val_f1_score: 0.1538 - val_loss: 1.3417 - val_precision: 1.0000 - val_recall: 0.0833
# Epoch 47/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4722 - f1_score: 0.2195 - loss: 1.3154 - precision: 0.9000 - recall: 0.1250
# Epoch 47: val_f1_score did not improve from 0.36364
#
# Epoch 47: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4722 - f1_score: 0.2195 - loss: 1.3154 - precision: 0.9000 - recall: 0.1250 - val_accuracy: 0.4167 - val_f1_score: 0.1333 - val_loss: 1.4359 - val_precision: 0.3333 - val_recall: 0.0833
# Epoch 48/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4583 - f1_score: 0.2766 - loss: 1.3220 - precision: 0.5909 - recall: 0.1806
# Epoch 48: val_f1_score did not improve from 0.36364
#
# Epoch 48: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.4583 - f1_score: 0.2766 - loss: 1.3220 - precision: 0.5909 - recall: 0.1806 - val_accuracy: 0.3333 - val_f1_score: 0.1429 - val_loss: 1.4232 - val_precision: 0.5000 - val_recall: 0.0833
# Epoch 49/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.3056 - f1_score: 0.2069 - loss: 1.4166 - precision: 0.6000 - recall: 0.1250
# Epoch 49: val_f1_score did not improve from 0.36364
#
# Epoch 49: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.3056 - f1_score: 0.2069 - loss: 1.4166 - precision: 0.6000 - recall: 0.1250 - val_accuracy: 0.2500 - val_f1_score: 0.2105 - val_loss: 1.5798 - val_precision: 0.2857 - val_recall: 0.1667
# Epoch 50/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3750 - f1_score: 0.3364 - loss: 1.4576 - precision: 0.5143 - recall: 0.2500
# Epoch 50: val_f1_score improved from 0.36364 to 0.40000, saving model to checkpoint_4obj_model_cnn_gru.keras
#
# Epoch 50: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step - accuracy: 0.3750 - f1_score: 0.3364 - loss: 1.4576 - precision: 0.5143 - recall: 0.2500 - val_accuracy: 0.3333 - val_f1_score: 0.4000 - val_loss: 1.3510 - val_precision: 0.5000 - val_recall: 0.3333
# Epoch 51/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4861 - f1_score: 0.4602 - loss: 1.2874 - precision: 0.6341 - recall: 0.3611
# Epoch 51: val_f1_score did not improve from 0.40000
#
# Epoch 51: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.4861 - f1_score: 0.4602 - loss: 1.2874 - precision: 0.6341 - recall: 0.3611 - val_accuracy: 0.4167 - val_f1_score: 0.4000 - val_loss: 1.4374 - val_precision: 0.5000 - val_recall: 0.3333
# Epoch 52/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4444 - f1_score: 0.4000 - loss: 1.3536 - precision: 0.5349 - recall: 0.3194
# Epoch 52: val_f1_score did not improve from 0.40000
#
# Epoch 52: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4444 - f1_score: 0.4000 - loss: 1.3536 - precision: 0.5349 - recall: 0.3194 - val_accuracy: 0.4167 - val_f1_score: 0.3000 - val_loss: 1.4691 - val_precision: 0.3750 - val_recall: 0.2500
# Epoch 53/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3889 - f1_score: 0.4000 - loss: 1.3576 - precision: 0.5000 - recall: 0.3333
# Epoch 53: val_f1_score improved from 0.40000 to 0.42105, saving model to checkpoint_4obj_model_cnn_gru.keras
#
# Epoch 53: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.3889 - f1_score: 0.4000 - loss: 1.3576 - precision: 0.5000 - recall: 0.3333 - val_accuracy: 0.4167 - val_f1_score: 0.4211 - val_loss: 1.3612 - val_precision: 0.5714 - val_recall: 0.3333
# Epoch 54/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3889 - f1_score: 0.3962 - loss: 1.3142 - precision: 0.6176 - recall: 0.2917
# Epoch 54: val_f1_score did not improve from 0.42105
#
# Epoch 54: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.3889 - f1_score: 0.3962 - loss: 1.3142 - precision: 0.6176 - recall: 0.2917 - val_accuracy: 0.3333 - val_f1_score: 0.3158 - val_loss: 1.4058 - val_precision: 0.4286 - val_recall: 0.2500
# Epoch 55/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3611 - f1_score: 0.3894 - loss: 1.2852 - precision: 0.5366 - recall: 0.3056
# Epoch 55: val_f1_score did not improve from 0.42105
#
# Epoch 55: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.3611 - f1_score: 0.3894 - loss: 1.2852 - precision: 0.5366 - recall: 0.3056 - val_accuracy: 0.3333 - val_f1_score: 0.3529 - val_loss: 1.2539 - val_precision: 0.6000 - val_recall: 0.2500
# Epoch 56/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3611 - f1_score: 0.4510 - loss: 1.1888 - precision: 0.7667 - recall: 0.3194
# Epoch 56: val_f1_score did not improve from 0.42105
#
# Epoch 56: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.3611 - f1_score: 0.4510 - loss: 1.1888 - precision: 0.7667 - recall: 0.3194 - val_accuracy: 0.4167 - val_f1_score: 0.3529 - val_loss: 1.2748 - val_precision: 0.6000 - val_recall: 0.2500
# Epoch 57/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4722 - f1_score: 0.4464 - loss: 1.1604 - precision: 0.6250 - recall: 0.3472
# Epoch 57: val_f1_score did not improve from 0.42105
#
# Epoch 57: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4722 - f1_score: 0.4464 - loss: 1.1604 - precision: 0.6250 - recall: 0.3472 - val_accuracy: 0.4167 - val_f1_score: 0.3750 - val_loss: 1.2066 - val_precision: 0.7500 - val_recall: 0.2500
# Epoch 58/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4306 - f1_score: 0.4554 - loss: 1.1312 - precision: 0.7931 - recall: 0.3194
# Epoch 58: val_f1_score did not improve from 0.42105
#
# Epoch 58: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4306 - f1_score: 0.4554 - loss: 1.1312 - precision: 0.7931 - recall: 0.3194 - val_accuracy: 0.5000 - val_f1_score: 0.3529 - val_loss: 1.2421 - val_precision: 0.6000 - val_recall: 0.2500
# Epoch 59/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5000 - f1_score: 0.4643 - loss: 1.1191 - precision: 0.6500 - recall: 0.3611
# Epoch 59: val_f1_score did not improve from 0.42105
#
# Epoch 59: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5000 - f1_score: 0.4643 - loss: 1.1191 - precision: 0.6500 - recall: 0.3611 - val_accuracy: 0.5000 - val_f1_score: 0.3529 - val_loss: 1.1937 - val_precision: 0.6000 - val_recall: 0.2500
# Epoch 60/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5417 - f1_score: 0.4510 - loss: 1.1094 - precision: 0.7667 - recall: 0.3194
# Epoch 60: val_f1_score did not improve from 0.42105
#
# Epoch 60: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5417 - f1_score: 0.4510 - loss: 1.1094 - precision: 0.7667 - recall: 0.3194 - val_accuracy: 0.4167 - val_f1_score: 0.3158 - val_loss: 1.2531 - val_precision: 0.4286 - val_recall: 0.2500
# Epoch 61/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4861 - f1_score: 0.4576 - loss: 1.1197 - precision: 0.5870 - recall: 0.3750
# Epoch 61: val_f1_score did not improve from 0.42105
#
# Epoch 61: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4861 - f1_score: 0.4576 - loss: 1.1197 - precision: 0.5870 - recall: 0.3750 - val_accuracy: 0.4167 - val_f1_score: 0.3810 - val_loss: 1.2322 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 62/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5139 - f1_score: 0.4037 - loss: 1.1392 - precision: 0.5946 - recall: 0.3056
# Epoch 62: val_f1_score did not improve from 0.42105
#
# Epoch 62: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5139 - f1_score: 0.4037 - loss: 1.1392 - precision: 0.5946 - recall: 0.3056 - val_accuracy: 0.4167 - val_f1_score: 0.3333 - val_loss: 1.3075 - val_precision: 0.5000 - val_recall: 0.2500
# Epoch 63/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4583 - f1_score: 0.4737 - loss: 1.1807 - precision: 0.6429 - recall: 0.3750
# Epoch 63: val_f1_score did not improve from 0.42105
#
# Epoch 63: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.4583 - f1_score: 0.4737 - loss: 1.1807 - precision: 0.6429 - recall: 0.3750 - val_accuracy: 0.4167 - val_f1_score: 0.3810 - val_loss: 1.2442 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 64/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4444 - f1_score: 0.4696 - loss: 1.1505 - precision: 0.6279 - recall: 0.3750
# Epoch 64: val_f1_score did not improve from 0.42105
#
# Epoch 64: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.4444 - f1_score: 0.4696 - loss: 1.1505 - precision: 0.6279 - recall: 0.3750 - val_accuracy: 0.5000 - val_f1_score: 0.2667 - val_loss: 1.2539 - val_precision: 0.6667 - val_recall: 0.1667
# Epoch 65/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.5278 - f1_score: 0.3913 - loss: 1.1536 - precision: 0.9000 - recall: 0.2500
# Epoch 65: val_f1_score did not improve from 0.42105
#
# Epoch 65: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.5278 - f1_score: 0.3913 - loss: 1.1536 - precision: 0.9000 - recall: 0.2500 - val_accuracy: 0.5000 - val_f1_score: 0.3158 - val_loss: 1.2324 - val_precision: 0.4286 - val_recall: 0.2500
# Epoch 66/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5556 - f1_score: 0.4220 - loss: 1.0942 - precision: 0.6216 - recall: 0.3194
# Epoch 66: val_f1_score did not improve from 0.42105
#
# Epoch 66: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5556 - f1_score: 0.4220 - loss: 1.0942 - precision: 0.6216 - recall: 0.3194 - val_accuracy: 0.5000 - val_f1_score: 0.3529 - val_loss: 1.1629 - val_precision: 0.6000 - val_recall: 0.2500
# Epoch 67/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5417 - f1_score: 0.4356 - loss: 1.0733 - precision: 0.7586 - recall: 0.3056
# Epoch 67: val_f1_score did not improve from 0.42105
#
# Epoch 67: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5417 - f1_score: 0.4356 - loss: 1.0733 - precision: 0.7586 - recall: 0.3056 - val_accuracy: 0.4167 - val_f1_score: 0.3158 - val_loss: 1.1894 - val_precision: 0.4286 - val_recall: 0.2500
# Epoch 68/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5972 - f1_score: 0.4643 - loss: 1.0290 - precision: 0.6500 - recall: 0.3611
# Epoch 68: val_f1_score improved from 0.42105 to 0.44444, saving model to checkpoint_4obj_model_cnn_gru.keras
#
# Epoch 68: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.5972 - f1_score: 0.4643 - loss: 1.0290 - precision: 0.6500 - recall: 0.3611 - val_accuracy: 0.5000 - val_f1_score: 0.4444 - val_loss: 1.1644 - val_precision: 0.6667 - val_recall: 0.3333
# Epoch 69/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5417 - f1_score: 0.4587 - loss: 1.0688 - precision: 0.6757 - recall: 0.3472
# Epoch 69: val_f1_score did not improve from 0.44444
#
# Epoch 69: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5417 - f1_score: 0.4587 - loss: 1.0688 - precision: 0.6757 - recall: 0.3472 - val_accuracy: 0.4167 - val_f1_score: 0.2500 - val_loss: 1.4906 - val_precision: 0.5000 - val_recall: 0.1667
# Epoch 70/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4722 - f1_score: 0.3922 - loss: 1.3562 - precision: 0.6667 - recall: 0.2778
# Epoch 70: val_f1_score did not improve from 0.44444
#
# Epoch 70: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.4722 - f1_score: 0.3922 - loss: 1.3562 - precision: 0.6667 - recall: 0.2778 - val_accuracy: 0.4167 - val_f1_score: 0.2857 - val_loss: 1.2477 - val_precision: 1.0000 - val_recall: 0.1667
# Epoch 71/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5000 - f1_score: 0.3441 - loss: 1.1654 - precision: 0.7619 - recall: 0.2222
# Epoch 71: val_f1_score did not improve from 0.44444
#
# Epoch 71: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5000 - f1_score: 0.3441 - loss: 1.1654 - precision: 0.7619 - recall: 0.2222 - val_accuracy: 0.3333 - val_f1_score: 0.3810 - val_loss: 1.3345 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 72/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4722 - f1_score: 0.5246 - loss: 1.1760 - precision: 0.6400 - recall: 0.4444
# Epoch 72: val_f1_score did not improve from 0.44444
#
# Epoch 72: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4722 - f1_score: 0.5246 - loss: 1.1760 - precision: 0.6400 - recall: 0.4444 - val_accuracy: 0.4167 - val_f1_score: 0.1429 - val_loss: 1.4470 - val_precision: 0.5000 - val_recall: 0.0833
# Epoch 73/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5417 - f1_score: 0.1647 - loss: 1.3683 - precision: 0.5385 - recall: 0.0972
# Epoch 73: val_f1_score did not improve from 0.44444
#
# Epoch 73: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5417 - f1_score: 0.1647 - loss: 1.3683 - precision: 0.5385 - recall: 0.0972 - val_accuracy: 0.2500 - val_f1_score: 0.1250 - val_loss: 1.3622 - val_precision: 0.2500 - val_recall: 0.0833
# Epoch 74/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4028 - f1_score: 0.2474 - loss: 1.2445 - precision: 0.4800 - recall: 0.1667
# Epoch 74: val_f1_score did not improve from 0.44444
#
# Epoch 74: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.4028 - f1_score: 0.2474 - loss: 1.2445 - precision: 0.4800 - recall: 0.1667 - val_accuracy: 0.5000 - val_f1_score: 0.2857 - val_loss: 1.1879 - val_precision: 1.0000 - val_recall: 0.1667
# Epoch 75/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5833 - f1_score: 0.3059 - loss: 1.1326 - precision: 1.0000 - recall: 0.1806
# Epoch 75: val_f1_score did not improve from 0.44444
#
# Epoch 75: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5833 - f1_score: 0.3059 - loss: 1.1326 - precision: 1.0000 - recall: 0.1806 - val_accuracy: 0.4167 - val_f1_score: 0.2500 - val_loss: 1.1854 - val_precision: 0.5000 - val_recall: 0.1667
# Epoch 76/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5694 - f1_score: 0.4124 - loss: 1.0477 - precision: 0.8000 - recall: 0.2778
# Epoch 76: val_f1_score improved from 0.44444 to 0.52632, saving model to checkpoint_4obj_model_cnn_gru.keras
#
# Epoch 76: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.5694 - f1_score: 0.4124 - loss: 1.0477 - precision: 0.8000 - recall: 0.2778 - val_accuracy: 0.5000 - val_f1_score: 0.5263 - val_loss: 1.1485 - val_precision: 0.7143 - val_recall: 0.4167
# Epoch 77/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5139 - f1_score: 0.4706 - loss: 1.0595 - precision: 0.8000 - recall: 0.3333
# Epoch 77: val_f1_score did not improve from 0.52632
#
# Epoch 77: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5139 - f1_score: 0.4706 - loss: 1.0595 - precision: 0.8000 - recall: 0.3333 - val_accuracy: 0.4167 - val_f1_score: 0.3529 - val_loss: 1.2719 - val_precision: 0.6000 - val_recall: 0.2500
# Epoch 78/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4722 - f1_score: 0.4815 - loss: 1.1097 - precision: 0.7222 - recall: 0.3611
# Epoch 78: val_f1_score did not improve from 0.52632
#
# Epoch 78: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.4722 - f1_score: 0.4815 - loss: 1.1097 - precision: 0.7222 - recall: 0.3611 - val_accuracy: 0.4167 - val_f1_score: 0.3158 - val_loss: 1.3128 - val_precision: 0.4286 - val_recall: 0.2500
# Epoch 79/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.4861 - f1_score: 0.3717 - loss: 1.1991 - precision: 0.5122 - recall: 0.2917
# Epoch 79: val_f1_score did not improve from 0.52632
#
# Epoch 79: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.4861 - f1_score: 0.3717 - loss: 1.1991 - precision: 0.5122 - recall: 0.2917 - val_accuracy: 0.4167 - val_f1_score: 0.4000 - val_loss: 1.3163 - val_precision: 0.5000 - val_recall: 0.3333
# Epoch 80/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4583 - f1_score: 0.4959 - loss: 1.1697 - precision: 0.6122 - recall: 0.4167
# Epoch 80: val_f1_score did not improve from 0.52632
#
# Epoch 80: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.4583 - f1_score: 0.4959 - loss: 1.1697 - precision: 0.6122 - recall: 0.4167 - val_accuracy: 0.5000 - val_f1_score: 0.4211 - val_loss: 1.1737 - val_precision: 0.5714 - val_recall: 0.3333
# Epoch 81/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5417 - f1_score: 0.4466 - loss: 1.0667 - precision: 0.7419 - recall: 0.3194
# Epoch 81: val_f1_score did not improve from 0.52632
#
# Epoch 81: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5417 - f1_score: 0.4466 - loss: 1.0667 - precision: 0.7419 - recall: 0.3194 - val_accuracy: 0.3333 - val_f1_score: 0.4211 - val_loss: 1.2132 - val_precision: 0.5714 - val_recall: 0.3333
# Epoch 82/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5000 - f1_score: 0.5217 - loss: 1.0563 - precision: 0.6977 - recall: 0.4167
# Epoch 82: val_f1_score did not improve from 0.52632
#
# Epoch 82: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5000 - f1_score: 0.5217 - loss: 1.0563 - precision: 0.6977 - recall: 0.4167 - val_accuracy: 0.4167 - val_f1_score: 0.3529 - val_loss: 1.1657 - val_precision: 0.6000 - val_recall: 0.2500
# Epoch 83/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4861 - f1_score: 0.4082 - loss: 1.0584 - precision: 0.7692 - recall: 0.2778
# Epoch 83: val_f1_score did not improve from 0.52632
#
# Epoch 83: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.4861 - f1_score: 0.4082 - loss: 1.0584 - precision: 0.7692 - recall: 0.2778 - val_accuracy: 0.5000 - val_f1_score: 0.4211 - val_loss: 1.1676 - val_precision: 0.5714 - val_recall: 0.3333
# Epoch 84/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6111 - f1_score: 0.5088 - loss: 1.0066 - precision: 0.6905 - recall: 0.4028
# Epoch 84: val_f1_score did not improve from 0.52632
#
# Epoch 84: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6111 - f1_score: 0.5088 - loss: 1.0066 - precision: 0.6905 - recall: 0.4028 - val_accuracy: 0.4167 - val_f1_score: 0.3750 - val_loss: 1.1241 - val_precision: 0.7500 - val_recall: 0.2500
# Epoch 85/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5972 - f1_score: 0.3656 - loss: 1.0105 - precision: 0.8095 - recall: 0.2361
# Epoch 85: val_f1_score did not improve from 0.52632
#
# Epoch 85: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5972 - f1_score: 0.3656 - loss: 1.0105 - precision: 0.8095 - recall: 0.2361 - val_accuracy: 0.5000 - val_f1_score: 0.4444 - val_loss: 1.1355 - val_precision: 0.6667 - val_recall: 0.3333
# Epoch 86/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6250 - f1_score: 0.5088 - loss: 0.9756 - precision: 0.6905 - recall: 0.4028
# Epoch 86: val_f1_score did not improve from 0.52632
#
# Epoch 86: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6250 - f1_score: 0.5088 - loss: 0.9756 - precision: 0.6905 - recall: 0.4028 - val_accuracy: 0.4167 - val_f1_score: 0.3529 - val_loss: 1.1127 - val_precision: 0.6000 - val_recall: 0.2500
# Epoch 87/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5972 - f1_score: 0.3656 - loss: 0.9906 - precision: 0.8095 - recall: 0.2361
# Epoch 87: val_f1_score did not improve from 0.52632
#
# Epoch 87: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.5972 - f1_score: 0.3656 - loss: 0.9906 - precision: 0.8095 - recall: 0.2361 - val_accuracy: 0.4167 - val_f1_score: 0.4211 - val_loss: 1.1205 - val_precision: 0.5714 - val_recall: 0.3333
# Epoch 88/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5833 - f1_score: 0.4737 - loss: 0.9619 - precision: 0.6429 - recall: 0.3750
# Epoch 88: val_f1_score did not improve from 0.52632
#
# Epoch 88: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5833 - f1_score: 0.4737 - loss: 0.9619 - precision: 0.6429 - recall: 0.3750 - val_accuracy: 0.5000 - val_f1_score: 0.2667 - val_loss: 1.1488 - val_precision: 0.6667 - val_recall: 0.1667
# Epoch 89/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5139 - f1_score: 0.4086 - loss: 1.0087 - precision: 0.9048 - recall: 0.2639
# Epoch 89: val_f1_score did not improve from 0.52632
#
# Epoch 89: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5139 - f1_score: 0.4086 - loss: 1.0087 - precision: 0.9048 - recall: 0.2639 - val_accuracy: 0.5000 - val_f1_score: 0.4762 - val_loss: 1.1997 - val_precision: 0.5556 - val_recall: 0.4167
# Epoch 90/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4861 - f1_score: 0.5246 - loss: 1.0435 - precision: 0.6400 - recall: 0.4444
# Epoch 90: val_f1_score did not improve from 0.52632
#
# Epoch 90: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.4861 - f1_score: 0.5246 - loss: 1.0435 - precision: 0.6400 - recall: 0.4444 - val_accuracy: 0.4167 - val_f1_score: 0.3333 - val_loss: 1.3476 - val_precision: 0.5000 - val_recall: 0.2500
# Epoch 91/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4167 - f1_score: 0.3922 - loss: 1.1828 - precision: 0.6667 - recall: 0.2778
# Epoch 91: val_f1_score did not improve from 0.52632
#
# Epoch 91: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4167 - f1_score: 0.3922 - loss: 1.1828 - precision: 0.6667 - recall: 0.2778 - val_accuracy: 0.4167 - val_f1_score: 0.4000 - val_loss: 1.2723 - val_precision: 0.5000 - val_recall: 0.3333
# Epoch 92/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4583 - f1_score: 0.4918 - loss: 1.1397 - precision: 0.6000 - recall: 0.4167
# Epoch 92: val_f1_score did not improve from 0.52632
#
# Epoch 92: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4583 - f1_score: 0.4918 - loss: 1.1397 - precision: 0.6000 - recall: 0.4167 - val_accuracy: 0.4167 - val_f1_score: 0.2667 - val_loss: 1.1048 - val_precision: 0.6667 - val_recall: 0.1667
# Epoch 93/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4861 - f1_score: 0.3958 - loss: 0.9762 - precision: 0.7917 - recall: 0.2639
# Epoch 93: val_f1_score did not improve from 0.52632
#
# Epoch 93: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4861 - f1_score: 0.3958 - loss: 0.9762 - precision: 0.7917 - recall: 0.2639 - val_accuracy: 0.5000 - val_f1_score: 0.4545 - val_loss: 1.1099 - val_precision: 0.5000 - val_recall: 0.4167
# Epoch 94/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5694 - f1_score: 0.5042 - loss: 0.9874 - precision: 0.6383 - recall: 0.4167
# Epoch 94: val_f1_score did not improve from 0.52632
#
# Epoch 94: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5694 - f1_score: 0.5042 - loss: 0.9874 - precision: 0.6383 - recall: 0.4167 - val_accuracy: 0.5000 - val_f1_score: 0.3529 - val_loss: 1.1028 - val_precision: 0.6000 - val_recall: 0.2500
# Epoch 95/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5278 - f1_score: 0.5185 - loss: 0.9607 - precision: 0.7778 - recall: 0.3889
# Epoch 95: val_f1_score did not improve from 0.52632
#
# Epoch 95: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5278 - f1_score: 0.5185 - loss: 0.9607 - precision: 0.7778 - recall: 0.3889 - val_accuracy: 0.4167 - val_f1_score: 0.3636 - val_loss: 1.1739 - val_precision: 0.4000 - val_recall: 0.3333
# Epoch 96/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4722 - f1_score: 0.4640 - loss: 1.0223 - precision: 0.5472 - recall: 0.4028
# Epoch 96: val_f1_score did not improve from 0.52632
#
# Epoch 96: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.4722 - f1_score: 0.4640 - loss: 1.0223 - precision: 0.5472 - recall: 0.4028 - val_accuracy: 0.5000 - val_f1_score: 0.4211 - val_loss: 1.1589 - val_precision: 0.5714 - val_recall: 0.3333
# Epoch 97/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6111 - f1_score: 0.5299 - loss: 1.0281 - precision: 0.6889 - recall: 0.4306
# Epoch 97: val_f1_score did not improve from 0.52632
#
# Epoch 97: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6111 - f1_score: 0.5299 - loss: 1.0281 - precision: 0.6889 - recall: 0.4306 - val_accuracy: 0.3333 - val_f1_score: 0.3478 - val_loss: 1.2200 - val_precision: 0.3636 - val_recall: 0.3333
# Epoch 98/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5000 - f1_score: 0.5156 - loss: 1.0389 - precision: 0.5893 - recall: 0.4583
# Epoch 98: val_f1_score did not improve from 0.52632
#
# Epoch 98: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5000 - f1_score: 0.5156 - loss: 1.0389 - precision: 0.5893 - recall: 0.4583 - val_accuracy: 0.5833 - val_f1_score: 0.5263 - val_loss: 1.0998 - val_precision: 0.7143 - val_recall: 0.4167
# Epoch 99/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5833 - f1_score: 0.4706 - loss: 1.0010 - precision: 0.5957 - recall: 0.3889
# Epoch 99: val_f1_score did not improve from 0.52632
#
# Epoch 99: Learning Rate = 0.0010000000474974513
# ...
# Epoch 1968: val_f1_score did not improve from 1.00000
#
# Epoch 1968: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0111 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.8696 - val_loss: 0.2006 - val_precision: 0.9091 - val_recall: 0.8333
# Epoch 1969/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0096 - precision: 1.0000 - recall: 1.0000
# Epoch 1969: val_f1_score did not improve from 1.00000
#
# Epoch 1969: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0096 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.8696 - val_loss: 0.1939 - val_precision: 0.9091 - val_recall: 0.8333
# Epoch 1970/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0085 - precision: 1.0000 - recall: 1.0000
# Epoch 1970: val_f1_score did not improve from 1.00000
#
# Epoch 1970: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0085 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.8696 - val_loss: 0.1908 - val_precision: 0.9091 - val_recall: 0.8333
# Epoch 1971/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0076 - precision: 1.0000 - recall: 1.0000
# Epoch 1971: val_f1_score did not improve from 1.00000
#
# Epoch 1971: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0076 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.8696 - val_loss: 0.1859 - val_precision: 0.9091 - val_recall: 0.8333
# Epoch 1972/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0068 - precision: 1.0000 - recall: 1.0000
# Epoch 1972: val_f1_score did not improve from 1.00000
#
# Epoch 1972: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0068 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1831 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 1973/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0062 - precision: 1.0000 - recall: 1.0000
# Epoch 1973: val_f1_score did not improve from 1.00000
#
# Epoch 1973: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0062 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1793 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 1974/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0057 - precision: 1.0000 - recall: 1.0000
# Epoch 1974: val_f1_score did not improve from 1.00000
#
# Epoch 1974: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0057 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1767 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 1975/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0052 - precision: 1.0000 - recall: 1.0000
# Epoch 1975: val_f1_score did not improve from 1.00000
#
# Epoch 1975: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0052 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1737 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 1976/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0048 - precision: 1.0000 - recall: 1.0000
# Epoch 1976: val_f1_score did not improve from 1.00000
#
# Epoch 1976: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0048 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1713 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 1977/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0044 - precision: 1.0000 - recall: 1.0000
# Epoch 1977: val_f1_score did not improve from 1.00000
#
# Epoch 1977: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0044 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1686 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 1978/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0041 - precision: 1.0000 - recall: 1.0000
# Epoch 1978: val_f1_score did not improve from 1.00000
#
# Epoch 1978: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0041 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1664 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 1979/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0038 - precision: 1.0000 - recall: 1.0000
# Epoch 1979: val_f1_score did not improve from 1.00000
#
# Epoch 1979: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0038 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1640 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 1980/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0036 - precision: 1.0000 - recall: 1.0000
# Epoch 1980: val_f1_score did not improve from 1.00000
#
# Epoch 1980: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0036 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1620 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 1981/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0033 - precision: 1.0000 - recall: 1.0000
# Epoch 1981: val_f1_score did not improve from 1.00000
#
# Epoch 1981: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0033 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1599 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 1982/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0031 - precision: 1.0000 - recall: 1.0000
# Epoch 1982: val_f1_score did not improve from 1.00000
#
# Epoch 1982: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0031 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1580 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 1983/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0029 - precision: 1.0000 - recall: 1.0000
# Epoch 1983: val_f1_score did not improve from 1.00000
#
# Epoch 1983: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0029 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1560 - val_precision: 0.9167 - val_recall: 0.9167
# Epoch 1984/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0028 - precision: 1.0000 - recall: 1.0000
# Epoch 1984: val_f1_score did not improve from 1.00000
#
# Epoch 1984: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0028 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9167 - val_f1_score: 0.9565 - val_loss: 0.1541 - val_precision: 1.0000 - val_recall: 0.9167
# Epoch 1985/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0026 - precision: 1.0000 - recall: 1.0000
# Epoch 1985: val_f1_score did not improve from 1.00000
#
# Epoch 1985: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0026 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 0.9565 - val_loss: 0.1523 - val_precision: 1.0000 - val_recall: 0.9167
# Epoch 1986/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0025 - precision: 1.0000 - recall: 1.0000
# Epoch 1986: val_f1_score did not improve from 1.00000
#
# Epoch 1986: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0025 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1505 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1987/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0023 - precision: 1.0000 - recall: 1.0000
# Epoch 1987: val_f1_score did not improve from 1.00000
#
# Epoch 1987: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0023 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1488 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1988/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0022 - precision: 1.0000 - recall: 1.0000
# Epoch 1988: val_f1_score did not improve from 1.00000
#
# Epoch 1988: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0022 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1472 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1989/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0021 - precision: 1.0000 - recall: 1.0000
# Epoch 1989: val_f1_score did not improve from 1.00000
#
# Epoch 1989: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0021 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1455 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1990/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0020 - precision: 1.0000 - recall: 1.0000
# Epoch 1990: val_f1_score did not improve from 1.00000
#
# Epoch 1990: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0020 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1439 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1991/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0019 - precision: 1.0000 - recall: 1.0000
# Epoch 1991: val_f1_score did not improve from 1.00000
#
# Epoch 1991: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0019 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1424 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1992/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0018 - precision: 1.0000 - recall: 1.0000
# Epoch 1992: val_f1_score did not improve from 1.00000
#
# Epoch 1992: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0018 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1408 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1993/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0017 - precision: 1.0000 - recall: 1.0000
# Epoch 1993: val_f1_score did not improve from 1.00000
#
# Epoch 1993: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0017 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1393 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1994/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0016 - precision: 1.0000 - recall: 1.0000
# Epoch 1994: val_f1_score did not improve from 1.00000
#
# Epoch 1994: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0016 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1378 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1995/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0016 - precision: 1.0000 - recall: 1.0000
# Epoch 1995: val_f1_score did not improve from 1.00000
#
# Epoch 1995: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0016 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1364 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1996/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0015 - precision: 1.0000 - recall: 1.0000
# Epoch 1996: val_f1_score did not improve from 1.00000
#
# Epoch 1996: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0015 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1350 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1997/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0014 - precision: 1.0000 - recall: 1.0000
# Epoch 1997: val_f1_score did not improve from 1.00000
#
# Epoch 1997: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0014 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1337 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1998/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0014 - precision: 1.0000 - recall: 1.0000
# Epoch 1998: val_f1_score did not improve from 1.00000
#
# Epoch 1998: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0014 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1323 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 1999/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0013 - precision: 1.0000 - recall: 1.0000
# Epoch 1999: val_f1_score did not improve from 1.00000
#
# Epoch 1999: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0013 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1309 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 2000/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0013 - precision: 1.0000 - recall: 1.0000
# Epoch 2000: val_f1_score did not improve from 1.00000
#
# Epoch 2000: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 1.0000 - f1_score: 1.0000 - loss: 0.0013 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.1297 - val_precision: 1.0000 - val_recall: 1.0000
