# %% [markdown]
# ### Binary Classification

# %%
# importing libraries
import math
import tensorflow as tf
import keras
from keras.layers import *
import numpy as np
import random
import io
import os
from sklearn.model_selection import train_test_split
from keras.activations import tanh, softmax, sigmoid
from keras.applications.inception_resnet_v2 import InceptionResNetV2
import tensorflow as tf
import random
import os
import keras
import matplotlib.pyplot as plt
import pandas as pd
from keras.layers import (
    LSTM,
    LSTMCell,
    Input,
    Dense,
    concatenate,
    TimeDistributed,
    Flatten,
    Dropout,
    Masking,
    RepeatVector,
    GlobalAveragePooling2D,
    GlobalMaxPooling2D,
    Reshape,
    multiply,
    Permute,
    Concatenate,
    Conv2D,
    Add,
    Activation,
    Lambda,
    BatchNormalization
)
from keras import backend as K, Model
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
# List all physical GPUs
gpus = tf.config.list_physical_devices('GPU')
print("Available GPUs:", gpus)

if gpus:
    try:
        # Select the first GPU (index 0)
        tf.config.set_visible_devices(gpus[5], 'GPU')

        # Optionally, limit GPU memory growth (prevents TensorFlow from consuming all GPU memory)
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        
        print("Using GPU:", gpus[5])
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:4', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:5', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:6', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:7', device_type='GPU')]
# Using GPU: PhysicalDevice(name='/physical_device:GPU:5', device_type='GPU')

# %%
# soft object
soft = np.asarray([1, 0])
# hard object
hard = np.asarray([0, 1])

# %%
# reading a numpy file
data_dir = './train_val_data'
samples_per_window = 30

def read_npy_files(directory):
  data = []
  labels = []
  for filename in os.listdir(directory):
    if filename.endswith(".npy"):
      base_name = os.path.splitext(filename)[0]
      data.append(np.load(os.path.join(directory, filename), allow_pickle = True))
      # print(np.asarray(data).shape)
      # for labelling
      label = []
      objects = ['phone cover', 'rubber', 'bottle']
      if any(object in filename for object in objects):
          label.append(np.tile(soft, (samples_per_window, 1)))
      else:
          label.append(np.tile(hard, (samples_per_window, 1)))
      label = np.asarray(label).reshape(samples_per_window, 2)
      # print(np.asarray(label).shape)
      labels.append(np.asarray(label))
  return data, labels

all_data, labels = read_npy_files(data_dir)

# converting to numpy array
all_data = np.asarray(all_data)[:, :, :, 1:]
labels = np.asarray(labels)

# %%
type(all_data), type(labels)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
all_data.shape, labels.shape
# Out:
# ((12, 8, 30, 3), (12, 30, 2))

# %%
all_data[0, 0 , 0 , ]
# Out:
# array([0.002595324954017997, 0.10000000149011612, 38.55552925554677],
#       dtype=object)

# %%
train_all_data = []
val_all_data = []
test_all_data =[]
train_labels = []
val_labels = []
test_labels = []
total_samples = 8
val_samples = 1
test_samples = 1
train_samples = total_samples - val_samples - test_samples


for data in all_data:
  for i in range(train_samples):
    train_all_data.append(data[i])
  for i in range(val_samples):
    val_all_data.append(data[train_samples + i])
  for i in range(test_samples):
    test_all_data.append(data[train_samples + val_samples + i])

for label in labels:
  # label = np.expand_dims(label[1, :], axis = 0)
  # print(np.asarray(label).shape)
  for i in range(train_samples):
    train_labels.append(label[1, :])
  for i in range(val_samples):
    val_labels.append(label[1, :])
  for i in range(test_samples):
    test_labels.append(label[1, :])

# %%
np.asarray(train_all_data).shape
# Out:
# (72, 30, 3)

# %%
np.asarray(train_labels).shape
# Out:
# (72, 2)

# %%
np.asarray(val_all_data).shape
# Out:
# (12, 30, 3)

# %%
np.asarray(val_labels).shape
# Out:
# (12, 2)

# %%
np.asarray(test_all_data).shape
# Out:
# (12, 30, 3)

# %%
np.asarray(test_labels).shape
# Out:
# (12, 2)

# %%
labels[0][0]
# Out:
# array([1, 0])

# %%
# hyperpaprameters
TIME_STEPS = 30
input_dim  = 3
output_dim = 2

# UNITS_DENSE = 128
UNITS_LSTM = 2048

DROPOUT_STRENGTH = 0.2
RECURRENT_DROPOUT_STRENGTH = 0.4

BIAS_INITIALIZER = "ones"
KERNEL_INITIALIZER = "VarianceScaling"

# %%
class LSTM_cell:
    def __init__(self, time_steps = TIME_STEPS,
                 dim_2 = input_dim,
                 lstm_units=UNITS_LSTM,
                 dropout=DROPOUT_STRENGTH,
                 rec_dropout=RECURRENT_DROPOUT_STRENGTH,
                 kernel_initializer=KERNEL_INITIALIZER,
                 bias_initializer=BIAS_INITIALIZER):

        self.time_steps = time_steps
        self.dim_2 = dim_2

        self.dropout = dropout
        self.rec_dropout = rec_dropout
        self.bias_initializer = bias_initializer
        self.kernel_initializer = kernel_initializer

        self.lstm_units = lstm_units
        # self.dense_units = dense_units

    def input_encoding_lstm(self, inputs):
        lstm_input = inputs
        lstm_hidden_states, hidden_state, c = LSTM(
            self.lstm_units, kernel_initializer=self.kernel_initializer, return_sequences=True,
            return_state=True,
            recurrent_dropout=self.rec_dropout,
            bias_initializer=self.bias_initializer,
            name='lstm_output'
        )(lstm_input)

        context_features = Dense(output_dim)(hidden_state)
        out = softmax(context_features, axis = 1)
        return out

    def generate(self):
        input_to_lstm = Input(shape=(self.time_steps, self.dim_2), name='lstm_input')

        output_from_lstm = self.input_encoding_lstm(input_to_lstm)
        model = Model(inputs = input_to_lstm, outputs = output_from_lstm)
        return model

# %%
lstm = LSTM_cell()
model = lstm.generate()

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_input (InputLayer)         │ (None, 30, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_output (LSTM)              │ [(None, 30, 2048),     │    16,809,984 │
# │                                 │ (None, 2048), (None,   │               │
# │                                 │ 2048)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │         4,098 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ softmax_1 (Softmax)             │ (None, 2)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,814,082 (64.14 MB)
#  Trainable params: 16,814,082 (64.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint_filepath = 'checkpoint_model.keras'
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath = checkpoint_filepath,
    monitor = 'val_f1_score',
    mode = 'max',
    verbose = 1,
    save_best_only = True,
    save_weights_only = False
)

precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()

def f1_score(y_true, y_pred):
    precision_value = precision(y_true, y_pred)
    recall_value = recall(y_true, y_pred)
    f1 = 2 * ((precision_value * recall_value) / (precision_value + recall_value + tf.keras.backend.epsilon()))
    return f1

# Early stopping criteria
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy', precision, recall, f1_score])

class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, validation_data):
        super(MetricsCallback, self).__init__()
        self.validation_data = validation_data

    def on_train_begin(self, logs = None):
        self.train_losses = []
        self.val_losses = []
        self.val_acc = []
        self.precision = []
        self.recall = []
        self.f1 = []

    # def on_epoch_end(self, epoch, logs = None):
        # val_pred = tf.convert_to_tensor(np.round(self.model.predict(self.validation_data[0])))
        # print(val_pred)
        # flatten_val_pred = tf.reshape(val_pred, [-1])
        # print(flatten_val_pred)
        # val_true = self.validation_data[1]
        # print(val_true)
        # flatten_val_true = tf.reshape(val_true, [-1])
        # # print(f'Precision : {precision_score(val_true, val_pred, average=None)}')
        # self.precision.append(precision_score(val_true, val_pred, average='weighted'))
        # self.recall.append(recall_score(val_true, val_pred, average='weighted'))
        # self.f1.append(f1_score(val_true, val_pred, average='weighted'))
        # # Create a figure and two subplots
        # fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
        # # plotting the precison, recall and f1_score
        # ax1.plot(self.precision, label='Precision', marker = 'o', markersize = 4)
        # ax1.plot(self.recall, label='Recall', marker = 'o', markersize = 4)
        # ax1.plot(self.f1, label='F1 Score', marker = 'o', markersize = 4)
        # ax1.set_title('Confusion matrix metrics')
        # ax1.set_xlabel('Epochs')
        # ax1.set_ylabel('Score')
        # ax1.legend()
        # # plot the losses
        # self.train_losses.append(logs['loss'])
        # self.val_losses.append(logs['val_loss'])
        # self.val_acc.append(logs['val_accuracy'])
        # # print(self.train_losses, self.val_losses, self.val_acc)
        # ax2.plot(self.train_losses, label = 'training loss', marker = 'o', markersize = 4)
        # ax2.plot(self.val_losses, label = 'validation loss', marker = 'o', markersize = 4)
        # ax2.plot(self.val_acc, label = 'validation accuracy', marker = 'o', markersize = 4)
        # ax2.set_title('Training Loss And Validation Loss and accuracy curves')
        # ax2.set_xlabel('Epochs')
        # ax2.set_ylabel('Loss')
        # ax2.legend()
        # plt.show()
        # plot the losses
        # self.train_losses.append(logs['loss'])
        # self.val_losses.append(logs['val_loss'])
        # self.val_acc.append(logs['val_accuracy'])
        # print(self.train_losses, self.val_losses, self.val_acc)
        
        # plt.plot(self.train_losses, label = 'training loss', marker = 'o', markersize = 4)
        # plt.plot(self.val_losses, label = 'validation loss', marker = 'o', markersize = 4)
        # plt.plot(self.val_acc, label = 'validation accuracy', marker = 'o', markersize = 4)
        # plt.title('Training Loss And Validation Loss and accuracy curves')
        # plt.xlabel('Epochs')
        # plt.ylabel('Loss')
        # plt.legend()
        # plt.show()


train_all_data = tf.convert_to_tensor(train_all_data)
train_labels = tf.convert_to_tensor(train_labels)
val_all_data = tf.convert_to_tensor(val_all_data)
val_labels = tf.convert_to_tensor(val_labels)
validation_data=(val_all_data, val_labels)

history = model.fit(train_all_data, train_labels, epochs = 100, batch_size = 128,
          validation_data = validation_data, callbacks = [model_checkpoint_callback, MetricsCallback(validation_data)])

# for tracking the maximum validation accuracy ata particular epoch
# val_acc_list = np.asarray(history.history['val_accuracy'])
# max_val_acc = (val_acc_list).max()

# print(max_val_acc, np.where(val_acc_list == max_val_acc)[0] + 1)

# plotting the graph
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_accuracy'], label='Validaton accuracy')
plt.plot(history.history['val_f1_score'], label='Validaton F-score')
plt.title('Training and Validation Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3472 - f1_score: 0.3472 - loss: 0.7376 - precision_1: 0.3472 - recall_1: 0.3472
# Epoch 1: val_f1_score improved from -inf to 0.75000, saving model to checkpoint_model.keras
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0
- precision_1: 0.9028 - recall_1: 0.9028
# Epoch 66: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.9028 - f1_score: 0.9028 - loss: 0.2210 - precision_1: 0.9028 - recall_1: 0.9028 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1838 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9306 - f1_score: 0.9306 - loss: 0.2035 - precision_1: 0.9306 - recall_1: 0.9306
# Epoch 67: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.9306 - f1_score: 0.9306 - loss: 0.2035 - precision_1: 0.9306 - recall_1: 0.9306 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1719 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8750 - f1_score: 0.8750 - loss: 0.2381 - precision_1: 0.8750 - recall_1: 0.8750
# Epoch 68: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.8750 - f1_score: 0.8750 - loss: 0.2381 - precision_1: 0.8750 - recall_1: 0.8750 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1699 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9028 - f1_score: 0.9028 - loss: 0.2190 - precision_1: 0.9028 - recall_1: 0.9028
# Epoch 69: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.9028 - f1_score: 0.9028 - loss: 0.2190 - precision_1: 0.9028 - recall_1: 0.9028 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1660 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9444 - f1_score: 0.9444 - loss: 0.2090 - precision_1: 0.9444 - recall_1: 0.9444
# Epoch 70: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - accuracy: 0.9444 - f1_score: 0.9444 - loss: 0.2090 - precision_1: 0.9444 - recall_1: 0.9444 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1805 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9306 - f1_score: 0.9306 - loss: 0.2215 - precision_1: 0.9306 - recall_1: 0.9306
# Epoch 71: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9306 - f1_score: 0.9306 - loss: 0.2215 - precision_1: 0.9306 - recall_1: 0.9306 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1910 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2045 - precision_1: 0.9167 - recall_1: 0.9167
# Epoch 72: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2045 - precision_1: 0.9167 - recall_1: 0.9167 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1760 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2277 - precision_1: 0.9167 - recall_1: 0.9167
# Epoch 73: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2277 - precision_1: 0.9167 - recall_1: 0.9167 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1645 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9028 - f1_score: 0.9028 - loss: 0.2156 - precision_1: 0.9028 - recall_1: 0.9028
# Epoch 74: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9028 - f1_score: 0.9028 - loss: 0.2156 - precision_1: 0.9028 - recall_1: 0.9028 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1505 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8750 - f1_score: 0.8750 - loss: 0.2253 - precision_1: 0.8750 - recall_1: 0.8750
# Epoch 75: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.8750 - f1_score: 0.8750 - loss: 0.2253 - precision_1: 0.8750 - recall_1: 0.8750 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1454 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8333 - f1_score: 0.8333 - loss: 0.2584 - precision_1: 0.8333 - recall_1: 0.8333
# Epoch 76: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8333 - f1_score: 0.8333 - loss: 0.2584 - precision_1: 0.8333 - recall_1: 0.8333 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1557 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9028 - f1_score: 0.9028 - loss: 0.2069 - precision_1: 0.9028 - recall_1: 0.9028
# Epoch 77: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9028 - f1_score: 0.9028 - loss: 0.2069 - precision_1: 0.9028 - recall_1: 0.9028 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1734 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2337 - precision_1: 0.8889 - recall_1: 0.8889
# Epoch 78: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2337 - precision_1: 0.8889 - recall_1: 0.8889 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1829 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2348 - precision_1: 0.9167 - recall_1: 0.9167
# Epoch 79: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2348 - precision_1: 0.9167 - recall_1: 0.9167 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1813 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2118 - precision_1: 0.9167 - recall_1: 0.9167
# Epoch 80: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2118 - precision_1: 0.9167 - recall_1: 0.9167 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1681 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2315 - precision_1: 0.9167 - recall_1: 0.9167
# Epoch 81: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2315 - precision_1: 0.9167 - recall_1: 0.9167 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1601 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.1936 - precision_1: 0.9167 - recall_1: 0.9167
# Epoch 82: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.1936 - precision_1: 0.9167 - recall_1: 0.9167 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1634 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2324 - precision_1: 0.8889 - recall_1: 0.8889
# Epoch 83: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2324 - precision_1: 0.8889 - recall_1: 0.8889 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1660 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2311 - precision_1: 0.8889 - recall_1: 0.8889
# Epoch 84: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2311 - precision_1: 0.8889 - recall_1: 0.8889 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1805 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2258 - precision_1: 0.8889 - recall_1: 0.8889
# Epoch 85: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2258 - precision_1: 0.8889 - recall_1: 0.8889 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1973 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2057 - precision_1: 0.8889 - recall_1: 0.8889
# Epoch 86: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2057 - precision_1: 0.8889 - recall_1: 0.8889 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1782 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9028 - f1_score: 0.9028 - loss: 0.2009 - precision_1: 0.9028 - recall_1: 0.9028
# Epoch 87: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9028 - f1_score: 0.9028 - loss: 0.2009 - precision_1: 0.9028 - recall_1: 0.9028 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1624 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8611 - f1_score: 0.8611 - loss: 0.2654 - precision_1: 0.8611 - recall_1: 0.8611
# Epoch 88: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8611 - f1_score: 0.8611 - loss: 0.2654 - precision_1: 0.8611 - recall_1: 0.8611 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1578 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2256 - precision_1: 0.8889 - recall_1: 0.8889
# Epoch 89: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2256 - precision_1: 0.8889 - recall_1: 0.8889 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1578 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2115 - precision_1: 0.9167 - recall_1: 0.9167
# Epoch 90: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2115 - precision_1: 0.9167 - recall_1: 0.9167 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1710 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2186 - precision_1: 0.8889 - recall_1: 0.8889
# Epoch 91: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2186 - precision_1: 0.8889 - recall_1: 0.8889 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1921 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2156 - precision_1: 0.8889 - recall_1: 0.8889
# Epoch 92: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2156 - precision_1: 0.8889 - recall_1: 0.8889 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1930 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2087 - precision_1: 0.9167 - recall_1: 0.9167
# Epoch 93: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2087 - precision_1: 0.9167 - recall_1: 0.9167 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1714 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2230 - precision_1: 0.8889 - recall_1: 0.8889
# Epoch 94: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2230 - precision_1: 0.8889 - recall_1: 0.8889 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1594 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2169 - precision_1: 0.8889 - recall_1: 0.8889
# Epoch 95: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.8889 - f1_score: 0.8889 - loss: 0.2169 - precision_1: 0.8889 - recall_1: 0.8889 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1587 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8611 - f1_score: 0.8611 - loss: 0.2351 - precision_1: 0.8611 - recall_1: 0.8611
# Epoch 96: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8611 - f1_score: 0.8611 - loss: 0.2351 - precision_1: 0.8611 - recall_1: 0.8611 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1656 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9306 - f1_score: 0.9306 - loss: 0.2173 - precision_1: 0.9306 - recall_1: 0.9306
# Epoch 97: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9306 - f1_score: 0.9306 - loss: 0.2173 - precision_1: 0.9306 - recall_1: 0.9306 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1715 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9306 - f1_score: 0.9306 - loss: 0.2073 - precision_1: 0.9306 - recall_1: 0.9306
# Epoch 98: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9306 - f1_score: 0.9306 - loss: 0.2073 - precision_1: 0.9306 - recall_1: 0.9306 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1746 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9306 - f1_score: 0.9306 - loss: 0.2036 - precision_1: 0.9306 - recall_1: 0.9306
# Epoch 99: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9306 - f1_score: 0.9306 - loss: 0.2036 - precision_1: 0.9306 - recall_1: 0.9306 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1720 - val_precision_1: 0.9167 - val_recall_1: 0.9167
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2004 - precision_1: 0.9167 - recall_1: 0.9167
# Epoch 100: val_f1_score did not improve from 0.91667
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.9167 - f1_score: 0.9167 - loss: 0.2004 - precision_1: 0.9167 - recall_1: 0.9167 - val_accuracy: 0.9167 - val_f1_score: 0.9167 - val_loss: 0.1627 - val_precision_1: 0.9167 - val_recall_1: 0.9167
