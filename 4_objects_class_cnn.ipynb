# %% [markdown]
# ### 4 Objects Classification

# %%
# importing libraries
import math
import tensorflow as tf
import keras
from keras.layers import *
import numpy as np
import random
import io
import os
from sklearn.model_selection import train_test_split
from keras.activations import tanh, softmax, sigmoid
from keras.applications.inception_resnet_v2 import InceptionResNetV2
import tensorflow as tf
import random
import os
import keras
import matplotlib.pyplot as plt
import pandas as pd
from keras.layers import (
    LSTM,
    LSTMCell,
    Input,
    Dense,
    concatenate,
    TimeDistributed,
    Flatten,
    Dropout,
    Masking,
    RepeatVector,
    GlobalAveragePooling2D,
    GlobalMaxPooling2D,
    Reshape,
    multiply,
    Permute,
    Concatenate,
    Conv2D,
    Add,
    Activation,
    Lambda,
    BatchNormalization
)
from keras import backend as K, Model
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import precision_score, recall_score, f1_score
# Out:
# 2024-10-25 12:59:54.882197: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-25 12:59:54.952965: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-25 12:59:55.073980: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-25 12:59:55.109004: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-25 12:59:55.168885: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-25 12:59:58.017058: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# List all physical GPUs
gpus = tf.config.list_physical_devices('GPU')
print("Available GPUs:", gpus)

if gpus:
    try:
        # Select the first GPU (index 0)
        tf.config.set_visible_devices(gpus[5], 'GPU')

        # Optionally, limit GPU memory growth (prevents TensorFlow from consuming all GPU memory)
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        
        print("Using GPU:", gpus[5])
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)
# Out:
# Available GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:4', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:5', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:6', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:7', device_type='GPU')]
# Using GPU: PhysicalDevice(name='/physical_device:GPU:5', device_type='GPU')

# %%
# hard objects
plate = np.asarray([1, 0, 0, 0])
# soft objects
phone_cover = np.asarray([0, 1, 0, 0])
bottle = np.asarray([0, 0, 1, 0])
soft_rubber = np.asarray([0, 0, 0, 1])

# %%
encoded_objects = [plate, phone_cover, bottle, soft_rubber]

# %%
encoded_objects
# Out:
# [array([1, 0, 0, 0]),
#  array([0, 1, 0, 0]),
#  array([0, 0, 1, 0]),
#  array([0, 0, 0, 1])]

# %%
# reading a numpy file
data_dir = './train_val_data'
samples_per_window = 30

def read_npy_files(directory):
  data = []
  labels = []
  i = 0
  for filename in os.listdir(directory):
    if filename.endswith(".npy"):
      base_name = os.path.splitext(filename)[0]
      data.append(np.load(os.path.join(directory, filename), allow_pickle = True))
      # for labelling objects = ['plate', 'ball', 'cover', 'bottle', 'soft_rubber']
      if 'plate' in filename :
          labels.append(np.tile(encoded_objects[0], (samples_per_window, 1)))
      elif 'phone' in filename and 'cover' in filename :
          labels.append(np.tile(encoded_objects[1], (samples_per_window, 1)))
      elif 'bottle' in filename :
          labels.append(np.tile(encoded_objects[2], (samples_per_window, 1)))
      elif 'rubber' in filename :
          labels.append(np.tile(encoded_objects[3], (samples_per_window, 1)))
  return data, labels

all_data, labels = read_npy_files(data_dir)

# converting to numpy array
all_data = np.asarray(all_data)[:, :, :, 1:].astype(np.float32)
labels = np.asarray(labels).astype(np.float32)

# %%
all_data.shape
# Out:
# (12, 8, 30, 3)

# %%
labels.shape
# Out:
# (12, 30, 4)

# %% [markdown]
# Spitting of the train and val dataset

# %%
train_all_data = []
val_all_data = []
test_all_data =[]
train_labels = []
val_labels = []
test_labels = []
total_samples = 8
val_samples = 1
test_samples = 1
train_samples = total_samples - val_samples - test_samples


for data in all_data:
  for i in range(train_samples):
    train_all_data.append(data[i])
  for i in range(val_samples):
    val_all_data.append(data[train_samples + i])
  for i in range(test_samples):
    test_all_data.append(data[train_samples + val_samples + i])

for label in labels:
  # label = np.expand_dims(label[1, :], axis = 0)
  # print(np.asarray(label).shape)
  for i in range(train_samples):
    train_labels.append(label[1, :])
  for i in range(val_samples):
    val_labels.append(label[1, :])
  for i in range(test_samples):
    test_labels.append(label[1, :])

# %%
# hyperpaprametres
TIME_STEPS = 30
input_dim  = 3
output_dim = 4

# %%
class CNN_GRU_Model(tf.keras.Model):
    def __init__(self):
        super(CNN_GRU_Model, self).__init__()

        # 1D Convolutional layers (CNN part)
        self.conv1 = Conv1D(32, kernel_size=3, strides=1, activation='relu')
        self.conv2 = Conv1D(64, kernel_size=3, strides=2, activation='relu')
        self.conv3 = Conv1D(128, kernel_size=3, strides=5, activation='relu')

        # Batch Normalization layers
        self.bn1 = BatchNormalization()
        self.bn2 = BatchNormalization()

        # Max Pooling layer
        self.max_pool = MaxPooling1D(pool_size=2, strides=2)

        # # GRU layer
        # self.gru = GRU(1024)

        # Fully connected layer
        self.fc = Dense(4, activation='softmax')  # Output layer for 4-class classification

    def call(self, inputs):
        # x_cnn, x_gru = inputs
        x_cnn = inputs

        # CNN forward pass on (30, 3) input
        x_cnn = self.conv1(x_cnn)
        x_cnn = self.conv2(x_cnn)
        x_cnn = self.bn1(x_cnn)
        x_cnn = self.max_pool(x_cnn)
        x_cnn = self.conv3(x_cnn)
        x_cnn = self.bn2(x_cnn)
        x_cnn = Flatten()(x_cnn)

        # GRU forward pass on (30, 3) input
        # x_gru = self.gru(x_gru)

        # Concatenate CNN and GRU outputs
        # x = Concatenate()([x_cnn, x_gru])

        # Fully connected layer
        x = self.fc(x_cnn)

        return x
    
    def generate(self):
        # Input for CNN (time series data with shape (30, 3))
        cnn_input = Input(shape=(30, 3), name='cnn_input')

        # Input for GRU (time series data with shape (30, 3))
        # gru_input = Input(shape=(30, 3), name='gru_input')

        # Call the model's main forward pass (call method) with the inputs
        # output = self.call([cnn_input, gru_input])
        output = self.call(cnn_input)

        # Create a Keras Model instance
        # model = Model(inputs=[cnn_input, gru_input], outputs=output)
        model = Model(inputs= cnn_input, outputs=output)

        return model

# %%
cnn_gru = CNN_GRU_Model()
model = cnn_gru.generate()
# Out:
# 2024-10-25 13:00:04.078384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 45882 MB memory:  -> device: 5, name: NVIDIA RTX A6000, pci bus id: 0000:9b:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ cnn_input (InputLayer)          │ (None, 30, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 28, 32)         │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 13, 64)         │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 13, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 6, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 1, 128)         │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 1, 128)         │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,516 (127.02 KB)
#  Trainable params: 32,132 (125.52 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
checkpoint_filepath = 'checkpoint_4obj_model_cnn.keras'
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath = checkpoint_filepath,
    monitor = 'val_f1_score',
    mode = 'max',
    verbose = 1,
    save_best_only = True,
    save_weights_only = False)

precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()

def f1_score(y_true, y_pred):
    precision_value = precision(y_true, y_pred)
    recall_value = recall(y_true, y_pred)
    f1 = 2 * ((precision_value * recall_value) / (precision_value + recall_value + tf.keras.backend.epsilon()))
    return f1

# Early stopping criteria
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 3)

initial_lr = 1e-3
decay_rate = 0.5
# val_acc_list = np.asarray(history.history['val_accuracy'])
# max_val_acc = (val_acc_list).max()
# print(max_val_acc, np.where(val_acc_list == max_val_acc)[0] + 1)
optimizer = keras.optimizers.Adam(learning_rate = initial_lr)

model.compile( loss = 'categorical_crossentropy', metrics = ['accuracy', precision, recall, f1_score])

class MetricsCallback(tf.keras.callbacks.Callback):
    def __init__(self, validation_data):
        super(MetricsCallback, self).__init__()
        self.validation_data = validation_data
    def on_epoch_end(self, epoch, logs = None):
        lr = self.model.optimizer.learning_rate
        print(f"\nEpoch {epoch + 1}: Learning Rate = {lr.numpy()}")

class ReduceLROnPlateau(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs = None):
        # Decrease learning rate by 0.1 after each epoch
        lr = float(K.get_value(optimizer.learning_rate))
        if lr > 3.4e-44:
            lr = lr * 0.1
        K.set_value(optimizer.learning_rate, lr)
        print(f"\nEpoch {epoch + 1}: New Learning Rate = {lr}")

# converting the numpy arrays into tensor
train_data_tf = tf.convert_to_tensor(train_all_data)
train_labels_tf = tf.convert_to_tensor(train_labels)
val_data_tf = tf.convert_to_tensor(val_all_data)
val_labels_tf = tf.convert_to_tensor(val_labels)
validation_data = (val_data_tf, val_labels_tf)

# training and validating step
history = model.fit(train_data_tf, train_labels_tf, epochs = 2000, batch_size = 128,
          validation_data = validation_data, callbacks = [model_checkpoint_callback, MetricsCallback(validation_data)])

# for tracking the maximum validation accuracy ata particular epoch
# val_acc_list = np.asarray(history.history['val_accuracy'])
# max_val_acc = (val_acc_list).max()
# print(max_val_acc, np.where(val_acc_list == max_val_acc)[0] + 1)

# plotting the graph
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['val_accuracy'], label='validaton accuracy')
plt.plot(history.history['val_f1_score'], label='Validaton F-score')
plt.title('Training and Validation Loss Curves')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/2000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1729841412.486995 3029263 service.cc:146] XLA service 0x7f9e9002cd50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1729841412.487024 3029263 service.cc:154]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-10-25 13:00:12.705463: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-10-25 13:00:13.392942: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2024-10-25 13:00:15.630839: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_865', 12 bytes spill stores, 16 bytes spill loads
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - accuracy: 0.2500 - f1_score: 0.0000e+00 - loss: 1.7345 - precision: 0.0000e+00 - recall: 0.0000e+00
# I0000 00:00:1729841420.482205 3029263 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_f1_score improved from -inf to 0.00000, saving model to checkpoint_4obj_model_gru.keras
#
# Epoch 1: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 17s 17s/step - accuracy: 0.2500 - f1_score: 0.0000e+00 - loss: 1.7345 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.1667 - val_f1_score: 0.0000e+00 - val_loss: 1.3904 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.3750 - f1_score: 0.0800 - loss: 1.3572 - precision: 1.0000 - recall: 0.0417
# Epoch 2: val_f1_score did not improve from 0.00000
#
# Epoch 2: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.3750 - f1_score: 0.0800 - loss: 1.3572 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2639 - f1_score: 0.0800 - loss: 1.3453 - precision: 1.0000 - recall: 0.0417
# Epoch 3: val_f1_score did not improve from 0.00000
#
# Epoch 3: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.2639 - f1_score: 0.0800 - loss: 1.3453 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.1667 - val_f1_score: 0.0000e+00 - val_loss: 1.3899 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.2222 - f1_score: 0.0800 - loss: 1.3387 - precision: 1.0000 - recall: 0.0417
# Epoch 4: val_f1_score did not improve from 0.00000
#
# Epoch 4: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.2222 - f1_score: 0.0800 - loss: 1.3387 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.1667 - val_f1_score: 0.0000e+00 - val_loss: 1.3898 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2639 - f1_score: 0.0800 - loss: 1.3302 - precision: 1.0000 - recall: 0.0417
# Epoch 5: val_f1_score did not improve from 0.00000
#
# Epoch 5: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.2639 - f1_score: 0.0800 - loss: 1.3302 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3896 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3889 - f1_score: 0.0800 - loss: 1.3262 - precision: 1.0000 - recall: 0.0417
# Epoch 6: val_f1_score did not improve from 0.00000
#
# Epoch 6: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.3889 - f1_score: 0.0800 - loss: 1.3262 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3890 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.3750 - f1_score: 0.0800 - loss: 1.3208 - precision: 1.0000 - recall: 0.0417
# Epoch 7: val_f1_score did not improve from 0.00000
#
# Epoch 7: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3750 - f1_score: 0.0800 - loss: 1.3208 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3887 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.3472 - f1_score: 0.0533 - loss: 1.3281 - precision: 0.6667 - recall: 0.0278
# Epoch 8: val_f1_score did not improve from 0.00000
#
# Epoch 8: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.3472 - f1_score: 0.0533 - loss: 1.3281 - precision: 0.6667 - recall: 0.0278 - val_accuracy: 0.1667 - val_f1_score: 0.0000e+00 - val_loss: 1.3923 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4306 - f1_score: 0.0533 - loss: 1.3344 - precision: 0.6667 - recall: 0.0278
# Epoch 9: val_f1_score did not improve from 0.00000
#
# Epoch 9: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.4306 - f1_score: 0.0533 - loss: 1.3344 - precision: 0.6667 - recall: 0.0278 - val_accuracy: 0.1667 - val_f1_score: 0.0000e+00 - val_loss: 1.3918 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.3611 - f1_score: 0.0800 - loss: 1.3247 - precision: 1.0000 - recall: 0.0417
# Epoch 10: val_f1_score did not improve from 0.00000
#
# Epoch 10: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.3611 - f1_score: 0.0800 - loss: 1.3247 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.1667 - val_f1_score: 0.0000e+00 - val_loss: 1.3907 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3472 - f1_score: 0.0800 - loss: 1.3181 - precision: 1.0000 - recall: 0.0417
# Epoch 11: val_f1_score did not improve from 0.00000
#
# Epoch 11: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.3472 - f1_score: 0.0800 - loss: 1.3181 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.0833 - val_f1_score: 0.0000e+00 - val_loss: 1.3899 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3889 - f1_score: 0.0800 - loss: 1.3133 - precision: 1.0000 - recall: 0.0417
# Epoch 12: val_f1_score did not improve from 0.00000
#
# Epoch 12: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3889 - f1_score: 0.0800 - loss: 1.3133 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.1667 - val_f1_score: 0.0000e+00 - val_loss: 1.3892 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5000 - f1_score: 0.0800 - loss: 1.3086 - precision: 1.0000 - recall: 0.0417
# Epoch 13: val_f1_score did not improve from 0.00000
#
# Epoch 13: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5000 - f1_score: 0.0800 - loss: 1.3086 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.0833 - val_f1_score: 0.0000e+00 - val_loss: 1.3884 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5000 - f1_score: 0.0800 - loss: 1.3054 - precision: 1.0000 - recall: 0.0417
# Epoch 14: val_f1_score did not improve from 0.00000
#
# Epoch 14: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5000 - f1_score: 0.0800 - loss: 1.3054 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.1667 - val_f1_score: 0.0000e+00 - val_loss: 1.3879 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3750 - f1_score: 0.0800 - loss: 1.3009 - precision: 1.0000 - recall: 0.0417
# Epoch 15: val_f1_score did not improve from 0.00000
#
# Epoch 15: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.3750 - f1_score: 0.0800 - loss: 1.3009 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3884 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.5139 - f1_score: 0.0800 - loss: 1.2996 - precision: 1.0000 - recall: 0.0417
# Epoch 16: val_f1_score did not improve from 0.00000
#
# Epoch 16: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5139 - f1_score: 0.0800 - loss: 1.2996 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3880 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4861 - f1_score: 0.0800 - loss: 1.2958 - precision: 1.0000 - recall: 0.0417
# Epoch 17: val_f1_score did not improve from 0.00000
#
# Epoch 17: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.4861 - f1_score: 0.0800 - loss: 1.2958 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3876 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5000 - f1_score: 0.0800 - loss: 1.2928 - precision: 1.0000 - recall: 0.0417
# Epoch 18: val_f1_score did not improve from 0.00000
#
# Epoch 18: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.5000 - f1_score: 0.0800 - loss: 1.2928 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3880 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5000 - f1_score: 0.0800 - loss: 1.2889 - precision: 1.0000 - recall: 0.0417
# Epoch 19: val_f1_score did not improve from 0.00000
#
# Epoch 19: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.5000 - f1_score: 0.0800 - loss: 1.2889 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3879 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4722 - f1_score: 0.0800 - loss: 1.2860 - precision: 1.0000 - recall: 0.0417
# Epoch 20: val_f1_score did not improve from 0.00000
#
# Epoch 20: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.4722 - f1_score: 0.0800 - loss: 1.2860 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3876 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4861 - f1_score: 0.0800 - loss: 1.2828 - precision: 1.0000 - recall: 0.0417
# Epoch 21: val_f1_score did not improve from 0.00000
#
# Epoch 21: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4861 - f1_score: 0.0800 - loss: 1.2828 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3883 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5417 - f1_score: 0.0800 - loss: 1.2817 - precision: 1.0000 - recall: 0.0417
# Epoch 22: val_f1_score did not improve from 0.00000
#
# Epoch 22: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.5417 - f1_score: 0.0800 - loss: 1.2817 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3876 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 23/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4444 - f1_score: 0.0800 - loss: 1.2770 - precision: 1.0000 - recall: 0.0417
# Epoch 23: val_f1_score did not improve from 0.00000
#
# Epoch 23: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.4444 - f1_score: 0.0800 - loss: 1.2770 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3873 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 24/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4722 - f1_score: 0.0800 - loss: 1.2728 - precision: 1.0000 - recall: 0.0417
# Epoch 24: val_f1_score did not improve from 0.00000
#
# Epoch 24: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.4722 - f1_score: 0.0800 - loss: 1.2728 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3884 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 25/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4722 - f1_score: 0.0800 - loss: 1.2697 - precision: 1.0000 - recall: 0.0417
# Epoch 25: val_f1_score did not improve from 0.00000
#
# Epoch 25: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.4722 - f1_score: 0.0800 - loss: 1.2697 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3882 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 26/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.4167 - f1_score: 0.0800 - loss: 1.2673 - precision: 1.0000 - recall: 0.0417
# Epoch 26: val_f1_score did not improve from 0.00000
#
# Epoch 26: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4167 - f1_score: 0.0800 - loss: 1.2673 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3892 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 27/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.4861 - f1_score: 0.1053 - loss: 1.2637 - precision: 1.0000 - recall: 0.0556
# Epoch 27: val_f1_score did not improve from 0.00000
#
# Epoch 27: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.4861 - f1_score: 0.1053 - loss: 1.2637 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3882 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 28/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5139 - f1_score: 0.0800 - loss: 1.2650 - precision: 1.0000 - recall: 0.0417
# Epoch 28: val_f1_score did not improve from 0.00000
#
# Epoch 28: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5139 - f1_score: 0.0800 - loss: 1.2650 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3913 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 29/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.3889 - f1_score: 0.0789 - loss: 1.2812 - precision: 0.7500 - recall: 0.0417
# Epoch 29: val_f1_score did not improve from 0.00000
#
# Epoch 29: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.3889 - f1_score: 0.0789 - loss: 1.2812 - precision: 0.7500 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3937 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 30/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.3750 - f1_score: 0.0800 - loss: 1.2854 - precision: 1.0000 - recall: 0.0417
# Epoch 30: val_f1_score did not improve from 0.00000
#
# Epoch 30: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.3750 - f1_score: 0.0800 - loss: 1.2854 - precision: 1.0000 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3895 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 31/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.4861 - f1_score: 0.1053 - loss: 1.2614 - precision: 1.0000 - recall: 0.0556
# Epoch 31: val_f1_score did not improve from 0.00000
#
# Epoch 31: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4861 - f1_score: 0.1053 - loss: 1.2614 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3902 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 32/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4444 - f1_score: 0.1053 - loss: 1.2570 - precision: 1.0000 - recall: 0.0556
# Epoch 32: val_f1_score did not improve from 0.00000
#
# Epoch 32: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.4444 - f1_score: 0.1053 - loss: 1.2570 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3891 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 33/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5000 - f1_score: 0.1053 - loss: 1.2539 - precision: 1.0000 - recall: 0.0556
# Epoch 33: val_f1_score did not improve from 0.00000
#
# Epoch 33: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.5000 - f1_score: 0.1053 - loss: 1.2539 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3887 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 34/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5000 - f1_score: 0.1053 - loss: 1.2514 - precision: 1.0000 - recall: 0.0556
# Epoch 34: val_f1_score did not improve from 0.00000
#
# Epoch 34: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.5000 - f1_score: 0.1053 - loss: 1.2514 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3888 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 35/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5000 - f1_score: 0.1053 - loss: 1.2475 - precision: 1.0000 - recall: 0.0556
# Epoch 35: val_f1_score did not improve from 0.00000
#
# Epoch 35: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5000 - f1_score: 0.1053 - loss: 1.2475 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3887 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 36/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.4306 - f1_score: 0.1053 - loss: 1.2440 - precision: 1.0000 - recall: 0.0556
# Epoch 36: val_f1_score did not improve from 0.00000
#
# Epoch 36: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4306 - f1_score: 0.1053 - loss: 1.2440 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3887 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 37/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5000 - f1_score: 0.1053 - loss: 1.2433 - precision: 1.0000 - recall: 0.0556
# Epoch 37: val_f1_score did not improve from 0.00000
#
# Epoch 37: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5000 - f1_score: 0.1053 - loss: 1.2433 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 38/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4861 - f1_score: 0.0789 - loss: 1.2518 - precision: 0.7500 - recall: 0.0417
# Epoch 38: val_f1_score did not improve from 0.00000
#
# Epoch 38: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.4861 - f1_score: 0.0789 - loss: 1.2518 - precision: 0.7500 - recall: 0.0417 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3915 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 39/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3750 - f1_score: 0.1053 - loss: 1.2663 - precision: 1.0000 - recall: 0.0556
# Epoch 39: val_f1_score did not improve from 0.00000
#
# Epoch 39: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.3750 - f1_score: 0.1053 - loss: 1.2663 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3884 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 40/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.5000 - f1_score: 0.1053 - loss: 1.2471 - precision: 1.0000 - recall: 0.0556
# Epoch 40: val_f1_score did not improve from 0.00000
#
# Epoch 40: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5000 - f1_score: 0.1053 - loss: 1.2471 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3907 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 41/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4167 - f1_score: 0.1053 - loss: 1.2403 - precision: 1.0000 - recall: 0.0556
# Epoch 41: val_f1_score did not improve from 0.00000
#
# Epoch 41: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.4167 - f1_score: 0.1053 - loss: 1.2403 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3904 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 42/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4306 - f1_score: 0.1053 - loss: 1.2356 - precision: 1.0000 - recall: 0.0556
# Epoch 42: val_f1_score did not improve from 0.00000
#
# Epoch 42: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.4306 - f1_score: 0.1053 - loss: 1.2356 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3902 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 43/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5139 - f1_score: 0.1053 - loss: 1.2323 - precision: 1.0000 - recall: 0.0556
# Epoch 43: val_f1_score did not improve from 0.00000
#
# Epoch 43: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.5139 - f1_score: 0.1053 - loss: 1.2323 - precision: 1.0000 - recall: 0.0556 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3925 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 44/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5139 - f1_score: 0.1299 - loss: 1.2286 - precision: 1.0000 - recall: 0.0694
# Epoch 44: val_f1_score did not improve from 0.00000
#
# Epoch 44: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5139 - f1_score: 0.1299 - loss: 1.2286 - precision: 1.0000 - recall: 0.0694 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3921 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 45/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5139 - f1_score: 0.1299 - loss: 1.2256 - precision: 1.0000 - recall: 0.0694
# Epoch 45: val_f1_score did not improve from 0.00000
#
# Epoch 45: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5139 - f1_score: 0.1299 - loss: 1.2256 - precision: 1.0000 - recall: 0.0694 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3914 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 46/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5139 - f1_score: 0.1299 - loss: 1.2230 - precision: 1.0000 - recall: 0.0694
# Epoch 46: val_f1_score did not improve from 0.00000
#
# Epoch 46: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.5139 - f1_score: 0.1299 - loss: 1.2230 - precision: 1.0000 - recall: 0.0694 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3931 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 47/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5278 - f1_score: 0.1299 - loss: 1.2214 - precision: 1.0000 - recall: 0.0694
# Epoch 47: val_f1_score did not improve from 0.00000
#
# Epoch 47: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5278 - f1_score: 0.1299 - loss: 1.2214 - precision: 1.0000 - recall: 0.0694 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3911 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 48/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3750 - f1_score: 0.1772 - loss: 1.2216 - precision: 1.0000 - recall: 0.0972
# Epoch 48: val_f1_score did not improve from 0.00000
#
# Epoch 48: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.3750 - f1_score: 0.1772 - loss: 1.2216 - precision: 1.0000 - recall: 0.0972 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3928 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 49/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5278 - f1_score: 0.1538 - loss: 1.2166 - precision: 1.0000 - recall: 0.0833
# Epoch 49: val_f1_score did not improve from 0.00000
#
# Epoch 49: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5278 - f1_score: 0.1538 - loss: 1.2166 - precision: 1.0000 - recall: 0.0833 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3913 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 50/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5139 - f1_score: 0.1772 - loss: 1.2132 - precision: 1.0000 - recall: 0.0972
# Epoch 50: val_f1_score did not improve from 0.00000
#
# Epoch 50: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5139 - f1_score: 0.1772 - loss: 1.2132 - precision: 1.0000 - recall: 0.0972 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3918 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 51/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5278 - f1_score: 0.1538 - loss: 1.2090 - precision: 1.0000 - recall: 0.0833
# Epoch 51: val_f1_score did not improve from 0.00000
#
# Epoch 51: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5278 - f1_score: 0.1538 - loss: 1.2090 - precision: 1.0000 - recall: 0.0833 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3903 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 52/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5278 - f1_score: 0.2222 - loss: 1.2031 - precision: 1.0000 - recall: 0.1250
# Epoch 52: val_f1_score did not improve from 0.00000
#
# Epoch 52: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.5278 - f1_score: 0.2222 - loss: 1.2031 - precision: 1.0000 - recall: 0.1250 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3898 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 53/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5278 - f1_score: 0.1772 - loss: 1.2003 - precision: 1.0000 - recall: 0.0972
# Epoch 53: val_f1_score did not improve from 0.00000
#
# Epoch 53: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5278 - f1_score: 0.1772 - loss: 1.2003 - precision: 1.0000 - recall: 0.0972 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3908 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 54/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3750 - f1_score: 0.1519 - loss: 1.2178 - precision: 0.8571 - recall: 0.0833
# Epoch 54: val_f1_score did not improve from 0.00000
#
# Epoch 54: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.3750 - f1_score: 0.1519 - loss: 1.2178 - precision: 0.8571 - recall: 0.0833 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3920 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 55/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5000 - f1_score: 0.2439 - loss: 1.2156 - precision: 1.0000 - recall: 0.1389
# Epoch 55: val_f1_score did not improve from 0.00000
#
# Epoch 55: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5000 - f1_score: 0.2439 - loss: 1.2156 - precision: 1.0000 - recall: 0.1389 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3882 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 56/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5278 - f1_score: 0.2222 - loss: 1.2122 - precision: 1.0000 - recall: 0.1250
# Epoch 56: val_f1_score did not improve from 0.00000
#
# Epoch 56: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5278 - f1_score: 0.2222 - loss: 1.2122 - precision: 1.0000 - recall: 0.1250 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3925 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 57/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.4583 - f1_score: 0.2651 - loss: 1.2108 - precision: 1.0000 - recall: 0.1528
# Epoch 57: val_f1_score did not improve from 0.00000
#
# Epoch 57: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.4583 - f1_score: 0.2651 - loss: 1.2108 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3896 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 58/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.5139 - f1_score: 0.2439 - loss: 1.2059 - precision: 1.0000 - recall: 0.1389
# Epoch 58: val_f1_score did not improve from 0.00000
#
# Epoch 58: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.5139 - f1_score: 0.2439 - loss: 1.2059 - precision: 1.0000 - recall: 0.1389 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3898 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 59/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5278 - f1_score: 0.2651 - loss: 1.2050 - precision: 1.0000 - recall: 0.1528
# Epoch 59: val_f1_score did not improve from 0.00000
#
# Epoch 59: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5278 - f1_score: 0.2651 - loss: 1.2050 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3876 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 60/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5278 - f1_score: 0.1772 - loss: 1.2061 - precision: 1.0000 - recall: 0.0972
# Epoch 60: val_f1_score did not improve from 0.00000
#
# Epoch 60: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5278 - f1_score: 0.1772 - loss: 1.2061 - precision: 1.0000 - recall: 0.0972 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3871 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 61/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5278 - f1_score: 0.2651 - loss: 1.1999 - precision: 1.0000 - recall: 0.1528
# Epoch 61: val_f1_score did not improve from 0.00000
#
# Epoch 61: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5278 - f1_score: 0.2651 - loss: 1.1999 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 62/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5694 - f1_score: 0.2651 - loss: 1.2031 - precision: 1.0000 - recall: 0.1528
# Epoch 62: val_f1_score did not improve from 0.00000
#
# Epoch 62: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.5694 - f1_score: 0.2651 - loss: 1.2031 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3867 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 63/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5417 - f1_score: 0.2222 - loss: 1.1972 - precision: 1.0000 - recall: 0.1250
# Epoch 63: val_f1_score did not improve from 0.00000
#
# Epoch 63: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5417 - f1_score: 0.2222 - loss: 1.1972 - precision: 1.0000 - recall: 0.1250 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3863 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 64/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5556 - f1_score: 0.2651 - loss: 1.1910 - precision: 1.0000 - recall: 0.1528
# Epoch 64: val_f1_score did not improve from 0.00000
#
# Epoch 64: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5556 - f1_score: 0.2651 - loss: 1.1910 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3865 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 65/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5278 - f1_score: 0.2651 - loss: 1.1848 - precision: 1.0000 - recall: 0.1528
# Epoch 65: val_f1_score did not improve from 0.00000
#
# Epoch 65: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5278 - f1_score: 0.2651 - loss: 1.1848 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3872 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 66/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5417 - f1_score: 0.2651 - loss: 1.1778 - precision: 1.0000 - recall: 0.1528
# Epoch 66: val_f1_score did not improve from 0.00000
#
# Epoch 66: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.5417 - f1_score: 0.2651 - loss: 1.1778 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3853 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 67/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5417 - f1_score: 0.1282 - loss: 1.2255 - precision: 0.8333 - recall: 0.0694
# Epoch 67: val_f1_score did not improve from 0.00000
#
# Epoch 67: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.5417 - f1_score: 0.1282 - loss: 1.2255 - precision: 0.8333 - recall: 0.0694 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3962 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 68/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3889 - f1_score: 0.2651 - loss: 1.2373 - precision: 1.0000 - recall: 0.1528
# Epoch 68: val_f1_score did not improve from 0.00000
#
# Epoch 68: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.3889 - f1_score: 0.2651 - loss: 1.2373 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3867 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 69/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4167 - f1_score: 0.2439 - loss: 1.2200 - precision: 1.0000 - recall: 0.1389
# Epoch 69: val_f1_score did not improve from 0.00000
#
# Epoch 69: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4167 - f1_score: 0.2439 - loss: 1.2200 - precision: 1.0000 - recall: 0.1389 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3867 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 70/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - f1_score: 0.2651 - loss: 1.2133 - precision: 1.0000 - recall: 0.1528
# Epoch 70: val_f1_score did not improve from 0.00000
#
# Epoch 70: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5000 - f1_score: 0.2651 - loss: 1.2133 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3850 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 71/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5139 - f1_score: 0.2651 - loss: 1.2114 - precision: 1.0000 - recall: 0.1528
# Epoch 71: val_f1_score did not improve from 0.00000
#
# Epoch 71: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5139 - f1_score: 0.2651 - loss: 1.2114 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3849 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 72/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5139 - f1_score: 0.2439 - loss: 1.2074 - precision: 1.0000 - recall: 0.1389
# Epoch 72: val_f1_score did not improve from 0.00000
#
# Epoch 72: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.5139 - f1_score: 0.2439 - loss: 1.2074 - precision: 1.0000 - recall: 0.1389 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3847 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 73/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.4861 - f1_score: 0.2651 - loss: 1.2065 - precision: 1.0000 - recall: 0.1528
# Epoch 73: val_f1_score did not improve from 0.00000
#
# Epoch 73: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.4861 - f1_score: 0.2651 - loss: 1.2065 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3843 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 74/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5000 - f1_score: 0.2651 - loss: 1.2047 - precision: 1.0000 - recall: 0.1528
# Epoch 74: val_f1_score did not improve from 0.00000
#
# Epoch 74: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5000 - f1_score: 0.2651 - loss: 1.2047 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3827 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 75/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.5278 - f1_score: 0.2222 - loss: 1.1991 - precision: 1.0000 - recall: 0.1250
# Epoch 75: val_f1_score did not improve from 0.00000
#
# Epoch 75: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.5278 - f1_score: 0.2222 - loss: 1.1991 - precision: 1.0000 - recall: 0.1250 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3837 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 76/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5139 - f1_score: 0.2651 - loss: 1.1981 - precision: 1.0000 - recall: 0.1528
# Epoch 76: val_f1_score did not improve from 0.00000
#
# Epoch 76: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5139 - f1_score: 0.2651 - loss: 1.1981 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3853 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 77/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5972 - f1_score: 0.2651 - loss: 1.1933 - precision: 1.0000 - recall: 0.1528
# Epoch 77: val_f1_score did not improve from 0.00000
#
# Epoch 77: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5972 - f1_score: 0.2651 - loss: 1.1933 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.3333 - val_f1_score: 0.0000e+00 - val_loss: 1.3833 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 78/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5278 - f1_score: 0.2222 - loss: 1.1886 - precision: 1.0000 - recall: 0.1250
# Epoch 78: val_f1_score did not improve from 0.00000
#
# Epoch 78: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5278 - f1_score: 0.2222 - loss: 1.1886 - precision: 1.0000 - recall: 0.1250 - val_accuracy: 0.3333 - val_f1_score: 0.0000e+00 - val_loss: 1.3828 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 79/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5417 - f1_score: 0.2222 - loss: 1.1865 - precision: 1.0000 - recall: 0.1250
# Epoch 79: val_f1_score did not improve from 0.00000
#
# Epoch 79: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.5417 - f1_score: 0.2222 - loss: 1.1865 - precision: 1.0000 - recall: 0.1250 - val_accuracy: 0.3333 - val_f1_score: 0.0000e+00 - val_loss: 1.3844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 80/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5278 - f1_score: 0.2651 - loss: 1.1908 - precision: 1.0000 - recall: 0.1528
# Epoch 80: val_f1_score did not improve from 0.00000
#
# Epoch 80: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.5278 - f1_score: 0.2651 - loss: 1.1908 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3809 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 81/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5278 - f1_score: 0.2651 - loss: 1.1957 - precision: 1.0000 - recall: 0.1528
# Epoch 81: val_f1_score did not improve from 0.00000
#
# Epoch 81: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5278 - f1_score: 0.2651 - loss: 1.1957 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3843 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 82/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5278 - f1_score: 0.3059 - loss: 1.1881 - precision: 1.0000 - recall: 0.1806
# Epoch 82: val_f1_score did not improve from 0.00000
#
# Epoch 82: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5278 - f1_score: 0.3059 - loss: 1.1881 - precision: 1.0000 - recall: 0.1806 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3820 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 83/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5972 - f1_score: 0.2439 - loss: 1.1750 - precision: 1.0000 - recall: 0.1389
# Epoch 83: val_f1_score did not improve from 0.00000
#
# Epoch 83: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.5972 - f1_score: 0.2439 - loss: 1.1750 - precision: 1.0000 - recall: 0.1389 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3808 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 84/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5278 - f1_score: 0.2651 - loss: 1.1763 - precision: 1.0000 - recall: 0.1528
# Epoch 84: val_f1_score did not improve from 0.00000
#
# Epoch 84: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.5278 - f1_score: 0.2651 - loss: 1.1763 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3842 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 85/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5556 - f1_score: 0.2000 - loss: 1.1831 - precision: 1.0000 - recall: 0.1111
# Epoch 85: val_f1_score did not improve from 0.00000
#
# Epoch 85: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5556 - f1_score: 0.2000 - loss: 1.1831 - precision: 1.0000 - recall: 0.1111 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3799 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 86/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5556 - f1_score: 0.2857 - loss: 1.1686 - precision: 1.0000 - recall: 0.1667
# Epoch 86: val_f1_score did not improve from 0.00000
#
# Epoch 86: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5556 - f1_score: 0.2857 - loss: 1.1686 - precision: 1.0000 - recall: 0.1667 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3890 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 87/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5417 - f1_score: 0.3059 - loss: 1.1513 - precision: 1.0000 - recall: 0.1806
# Epoch 87: val_f1_score did not improve from 0.00000
#
# Epoch 87: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5417 - f1_score: 0.3059 - loss: 1.1513 - precision: 1.0000 - recall: 0.1806 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3793 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 88/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.3889 - f1_score: 0.3741 - loss: 1.4786 - precision: 0.3881 - recall: 0.3611
# Epoch 88: val_f1_score did not improve from 0.00000
#
# Epoch 88: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3889 - f1_score: 0.3741 - loss: 1.4786 - precision: 0.3881 - recall: 0.3611 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3824 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 89/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.4583 - f1_score: 0.2651 - loss: 1.2372 - precision: 1.0000 - recall: 0.1528
# Epoch 89: val_f1_score did not improve from 0.00000
#
# Epoch 89: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4583 - f1_score: 0.2651 - loss: 1.2372 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3804 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 90/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4583 - f1_score: 0.2222 - loss: 1.2209 - precision: 1.0000 - recall: 0.1250
# Epoch 90: val_f1_score did not improve from 0.00000
#
# Epoch 90: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.4583 - f1_score: 0.2222 - loss: 1.2209 - precision: 1.0000 - recall: 0.1250 - val_accuracy: 0.1667 - val_f1_score: 0.0000e+00 - val_loss: 1.3807 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 91/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4722 - f1_score: 0.2651 - loss: 1.2166 - precision: 1.0000 - recall: 0.1528
# Epoch 91: val_f1_score did not improve from 0.00000
#
# Epoch 91: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.4722 - f1_score: 0.2651 - loss: 1.2166 - precision: 1.0000 - recall: 0.1528 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3812 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 92/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5972 - f1_score: 0.2000 - loss: 1.2064 - precision: 1.0000 - recall: 0.1111
# Epoch 92: val_f1_score did not improve from 0.00000
#
# Epoch 92: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5972 - f1_score: 0.2000 - loss: 1.2064 - precision: 1.0000 - recall: 0.1111 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3811 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 93/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.5417 - f1_score: 0.1975 - loss: 1.1728 - precision: 0.8889 - recall: 0.1111
# Epoch 93: val_f1_score did not improve from 0.00000
#
# Epoch 93: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5417 - f1_score: 0.1975 - loss: 1.1728 - precision: 0.8889 - recall: 0.1111 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3774 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 94/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5000 - f1_score: 0.1772 - loss: 1.2237 - precision: 1.0000 - recall: 0.0972
# Epoch 94: val_f1_score did not improve from 0.00000
#
# Epoch 94: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5000 - f1_score: 0.1772 - loss: 1.2237 - precision: 1.0000 - recall: 0.0972 - val_accuracy: 0.2500 - val_f1_score: 0.0000e+00 - val_loss: 1.3820 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 95/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5000 - f1_score: 0.2651 - loss: 1.2172 - precision: 1.0000 - recall: 0.1528
# Epoch 95: val_f1_score did not improve from 0.00000
#
# Epoch 95: Learning Rate = 0.0010000000474974513
# ...
# Epoch 1968: val_f1_score did not improve from 0.43478
#
# Epoch 1968: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5694 - f1_score: 0.3448 - loss: 1.1328 - precision: 1.0000 - recall: 0.2083 - val_accuracy: 0.4167 - val_f1_score: 0.3810 - val_loss: 1.9734 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 1969/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5278 - f1_score: 0.3448 - loss: 1.1309 - precision: 1.0000 - recall: 0.2083
# Epoch 1969: val_f1_score did not improve from 0.43478
#
# Epoch 1969: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5278 - f1_score: 0.3448 - loss: 1.1309 - precision: 1.0000 - recall: 0.2083 - val_accuracy: 0.3333 - val_f1_score: 0.3333 - val_loss: 2.2286 - val_precision: 0.3333 - val_recall: 0.3333
# Epoch 1970/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5556 - f1_score: 0.3448 - loss: 1.1266 - precision: 1.0000 - recall: 0.2083
# Epoch 1970: val_f1_score did not improve from 0.43478
#
# Epoch 1970: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5556 - f1_score: 0.3448 - loss: 1.1266 - precision: 1.0000 - recall: 0.2083 - val_accuracy: 0.4167 - val_f1_score: 0.3000 - val_loss: 1.8153 - val_precision: 0.3750 - val_recall: 0.2500
# Epoch 1971/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5417 - f1_score: 0.3256 - loss: 1.1228 - precision: 1.0000 - recall: 0.1944
# Epoch 1971: val_f1_score did not improve from 0.43478
#
# Epoch 1971: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.5417 - f1_score: 0.3256 - loss: 1.1228 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.3810 - val_loss: 2.0374 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 1972/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5833 - f1_score: 0.3256 - loss: 1.1212 - precision: 1.0000 - recall: 0.1944
# Epoch 1972: val_f1_score did not improve from 0.43478
#
# Epoch 1972: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.5833 - f1_score: 0.3256 - loss: 1.1212 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.4167 - val_f1_score: 0.2857 - val_loss: 1.8971 - val_precision: 0.3333 - val_recall: 0.2500
# Epoch 1973/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5694 - f1_score: 0.3256 - loss: 1.1202 - precision: 1.0000 - recall: 0.1944
# Epoch 1973: val_f1_score did not improve from 0.43478
#
# Epoch 1973: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5694 - f1_score: 0.3256 - loss: 1.1202 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.3810 - val_loss: 2.0404 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 1974/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5694 - f1_score: 0.3256 - loss: 1.1209 - precision: 1.0000 - recall: 0.1944
# Epoch 1974: val_f1_score did not improve from 0.43478
#
# Epoch 1974: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5694 - f1_score: 0.3256 - loss: 1.1209 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.3636 - val_loss: 1.8385 - val_precision: 0.4000 - val_recall: 0.3333
# Epoch 1975/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5694 - f1_score: 0.3256 - loss: 1.1200 - precision: 1.0000 - recall: 0.1944
# Epoch 1975: val_f1_score did not improve from 0.43478
#
# Epoch 1975: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5694 - f1_score: 0.3256 - loss: 1.1200 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.3810 - val_loss: 2.0639 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 1976/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5694 - f1_score: 0.3256 - loss: 1.1199 - precision: 1.0000 - recall: 0.1944
# Epoch 1976: val_f1_score did not improve from 0.43478
#
# Epoch 1976: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5694 - f1_score: 0.3256 - loss: 1.1199 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.3478 - val_loss: 1.8456 - val_precision: 0.3636 - val_recall: 0.3333
# Epoch 1977/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5972 - f1_score: 0.3256 - loss: 1.1176 - precision: 1.0000 - recall: 0.1944
# Epoch 1977: val_f1_score did not improve from 0.43478
#
# Epoch 1977: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5972 - f1_score: 0.3256 - loss: 1.1176 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.3810 - val_loss: 2.0300 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 1978/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.5833 - f1_score: 0.3256 - loss: 1.1168 - precision: 1.0000 - recall: 0.1944
# Epoch 1978: val_f1_score did not improve from 0.43478
#
# Epoch 1978: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.5833 - f1_score: 0.3256 - loss: 1.1168 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.3636 - val_loss: 1.7810 - val_precision: 0.4000 - val_recall: 0.3333
# Epoch 1979/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.5278 - f1_score: 0.3059 - loss: 1.1159 - precision: 1.0000 - recall: 0.1806
# Epoch 1979: val_f1_score did not improve from 0.43478
#
# Epoch 1979: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.5278 - f1_score: 0.3059 - loss: 1.1159 - precision: 1.0000 - recall: 0.1806 - val_accuracy: 0.4167 - val_f1_score: 0.3810 - val_loss: 2.1153 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 1980/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5278 - f1_score: 0.3256 - loss: 1.1164 - precision: 1.0000 - recall: 0.1944
# Epoch 1980: val_f1_score did not improve from 0.43478
#
# Epoch 1980: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5278 - f1_score: 0.3256 - loss: 1.1164 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.3333 - val_loss: 1.6766 - val_precision: 0.5000 - val_recall: 0.2500
# Epoch 1981/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5278 - f1_score: 0.3059 - loss: 1.1173 - precision: 1.0000 - recall: 0.1806
# Epoch 1981: val_f1_score did not improve from 0.43478
#
# Epoch 1981: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.5278 - f1_score: 0.3059 - loss: 1.1173 - precision: 1.0000 - recall: 0.1806 - val_accuracy: 0.3333 - val_f1_score: 0.3810 - val_loss: 2.1828 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 1982/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.5000 - f1_score: 0.3256 - loss: 1.1173 - precision: 1.0000 - recall: 0.1944
# Epoch 1982: val_f1_score did not improve from 0.43478
#
# Epoch 1982: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5000 - f1_score: 0.3256 - loss: 1.1173 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.2857 - val_loss: 1.6805 - val_precision: 0.3333 - val_recall: 0.2500
# Epoch 1983/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5278 - f1_score: 0.3059 - loss: 1.1150 - precision: 1.0000 - recall: 0.1806
# Epoch 1983: val_f1_score did not improve from 0.43478
#
# Epoch 1983: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.5278 - f1_score: 0.3059 - loss: 1.1150 - precision: 1.0000 - recall: 0.1806 - val_accuracy: 0.4167 - val_f1_score: 0.3810 - val_loss: 2.1485 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 1984/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5694 - f1_score: 0.3256 - loss: 1.1130 - precision: 1.0000 - recall: 0.1944
# Epoch 1984: val_f1_score did not improve from 0.43478
#
# Epoch 1984: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5694 - f1_score: 0.3256 - loss: 1.1130 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.3636 - val_loss: 1.8326 - val_precision: 0.4000 - val_recall: 0.3333
# Epoch 1985/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.5278 - f1_score: 0.3448 - loss: 1.1117 - precision: 1.0000 - recall: 0.2083
# Epoch 1985: val_f1_score did not improve from 0.43478
#
# Epoch 1985: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5278 - f1_score: 0.3448 - loss: 1.1117 - precision: 1.0000 - recall: 0.2083 - val_accuracy: 0.3333 - val_f1_score: 0.3810 - val_loss: 2.2036 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 1986/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5000 - f1_score: 0.3256 - loss: 1.1147 - precision: 1.0000 - recall: 0.1944
# Epoch 1986: val_f1_score did not improve from 0.43478
#
# Epoch 1986: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5000 - f1_score: 0.3256 - loss: 1.1147 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.3158 - val_loss: 1.7094 - val_precision: 0.4286 - val_recall: 0.2500
# Epoch 1987/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5278 - f1_score: 0.3448 - loss: 1.1129 - precision: 1.0000 - recall: 0.2083
# Epoch 1987: val_f1_score did not improve from 0.43478
#
# Epoch 1987: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5278 - f1_score: 0.3448 - loss: 1.1129 - precision: 1.0000 - recall: 0.2083 - val_accuracy: 0.3333 - val_f1_score: 0.3478 - val_loss: 2.2696 - val_precision: 0.3636 - val_recall: 0.3333
# Epoch 1988/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4583 - f1_score: 0.3256 - loss: 1.1140 - precision: 1.0000 - recall: 0.1944
# Epoch 1988: val_f1_score did not improve from 0.43478
#
# Epoch 1988: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.4583 - f1_score: 0.3256 - loss: 1.1140 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.2857 - val_loss: 1.8372 - val_precision: 0.3333 - val_recall: 0.2500
# Epoch 1989/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5556 - f1_score: 0.3256 - loss: 1.1158 - precision: 1.0000 - recall: 0.1944
# Epoch 1989: val_f1_score did not improve from 0.43478
#
# Epoch 1989: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.5556 - f1_score: 0.3256 - loss: 1.1158 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.3333 - val_loss: 2.3970 - val_precision: 0.3333 - val_recall: 0.3333
# Epoch 1990/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.5278 - f1_score: 0.3256 - loss: 1.1122 - precision: 1.0000 - recall: 0.1944
# Epoch 1990: val_f1_score did not improve from 0.43478
#
# Epoch 1990: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.5278 - f1_score: 0.3256 - loss: 1.1122 - precision: 1.0000 - recall: 0.1944 - val_accuracy: 0.3333 - val_f1_score: 0.3636 - val_loss: 1.9373 - val_precision: 0.4000 - val_recall: 0.3333
# Epoch 1991/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5694 - f1_score: 0.3448 - loss: 1.1080 - precision: 1.0000 - recall: 0.2083
# Epoch 1991: val_f1_score did not improve from 0.43478
#
# Epoch 1991: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5694 - f1_score: 0.3448 - loss: 1.1080 - precision: 1.0000 - recall: 0.2083 - val_accuracy: 0.3333 - val_f1_score: 0.3333 - val_loss: 2.2970 - val_precision: 0.3333 - val_recall: 0.3333
# Epoch 1992/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5833 - f1_score: 0.3448 - loss: 1.1068 - precision: 1.0000 - recall: 0.2083
# Epoch 1992: val_f1_score did not improve from 0.43478
#
# Epoch 1992: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.5833 - f1_score: 0.3448 - loss: 1.1068 - precision: 1.0000 - recall: 0.2083 - val_accuracy: 0.4167 - val_f1_score: 0.2727 - val_loss: 2.0574 - val_precision: 0.3000 - val_recall: 0.2500
# Epoch 1993/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5278 - f1_score: 0.3448 - loss: 1.1074 - precision: 1.0000 - recall: 0.2083
# Epoch 1993: val_f1_score did not improve from 0.43478
#
# Epoch 1993: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5278 - f1_score: 0.3448 - loss: 1.1074 - precision: 1.0000 - recall: 0.2083 - val_accuracy: 0.3333 - val_f1_score: 0.3333 - val_loss: 2.5690 - val_precision: 0.3333 - val_recall: 0.3333
# Epoch 1994/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.4167 - f1_score: 0.3820 - loss: 1.1165 - precision: 1.0000 - recall: 0.2361
# Epoch 1994: val_f1_score did not improve from 0.43478
#
# Epoch 1994: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4167 - f1_score: 0.3820 - loss: 1.1165 - precision: 1.0000 - recall: 0.2361 - val_accuracy: 0.4167 - val_f1_score: 0.3158 - val_loss: 1.6836 - val_precision: 0.4286 - val_recall: 0.2500
# Epoch 1995/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5417 - f1_score: 0.3059 - loss: 1.1175 - precision: 1.0000 - recall: 0.1806
# Epoch 1995: val_f1_score did not improve from 0.43478
#
# Epoch 1995: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5417 - f1_score: 0.3059 - loss: 1.1175 - precision: 1.0000 - recall: 0.1806 - val_accuracy: 0.3333 - val_f1_score: 0.3333 - val_loss: 2.3622 - val_precision: 0.3333 - val_recall: 0.3333
# Epoch 1996/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5000 - f1_score: 0.3448 - loss: 1.1096 - precision: 1.0000 - recall: 0.2083
# Epoch 1996: val_f1_score did not improve from 0.43478
#
# Epoch 1996: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.5000 - f1_score: 0.3448 - loss: 1.1096 - precision: 1.0000 - recall: 0.2083 - val_accuracy: 0.4167 - val_f1_score: 0.3636 - val_loss: 1.8337 - val_precision: 0.4000 - val_recall: 0.3333
# Epoch 1997/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.5278 - f1_score: 0.3448 - loss: 1.1040 - precision: 1.0000 - recall: 0.2083
# Epoch 1997: val_f1_score did not improve from 0.43478
#
# Epoch 1997: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.5278 - f1_score: 0.3448 - loss: 1.1040 - precision: 1.0000 - recall: 0.2083 - val_accuracy: 0.3333 - val_f1_score: 0.3636 - val_loss: 2.0951 - val_precision: 0.4000 - val_recall: 0.3333
# Epoch 1998/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5972 - f1_score: 0.3448 - loss: 1.1040 - precision: 1.0000 - recall: 0.2083
# Epoch 1998: val_f1_score did not improve from 0.43478
#
# Epoch 1998: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5972 - f1_score: 0.3448 - loss: 1.1040 - precision: 1.0000 - recall: 0.2083 - val_accuracy: 0.3333 - val_f1_score: 0.3810 - val_loss: 2.0279 - val_precision: 0.4444 - val_recall: 0.3333
# Epoch 1999/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5278 - f1_score: 0.3448 - loss: 1.1037 - precision: 1.0000 - recall: 0.2083
# Epoch 1999: val_f1_score did not improve from 0.43478
#
# Epoch 1999: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5278 - f1_score: 0.3448 - loss: 1.1037 - precision: 1.0000 - recall: 0.2083 - val_accuracy: 0.3333 - val_f1_score: 0.3333 - val_loss: 2.3055 - val_precision: 0.3333 - val_recall: 0.3333
# Epoch 2000/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5972 - f1_score: 0.3636 - loss: 1.1032 - precision: 1.0000 - recall: 0.2222
# Epoch 2000: val_f1_score did not improve from 0.43478
#
# Epoch 2000: Learning Rate = 0.0010000000474974513
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.5972 - f1_score: 0.3636 - loss: 1.1032 - precision: 1.0000 - recall: 0.2222 - val_accuracy: 0.3333 - val_f1_score: 0.3636 - val_loss: 1.9877 - val_precision: 0.4000 - val_recall: 0.3333
